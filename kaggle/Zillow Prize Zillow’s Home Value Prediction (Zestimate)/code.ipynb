# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split
import gc
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 0. Өгөгдлөө унших, бэлтгэх

# %% [markdown]
# ## 0.1 Өгөгдөл унших

# %%
print('Loading Properties...')
properties2016 = pd.read_csv('../input/properties_2016.csv', low_memory = False)
properties2017 = pd.read_csv('../input/properties_2017.csv', low_memory = False)

print('Loading Train...')
train2016 = pd.read_csv('../input/train_2016_v2.csv', parse_dates=['transactiondate'], low_memory=False)
train2017 = pd.read_csv('../input/train_2017.csv', parse_dates=['transactiondate'], low_memory=False)

print('Loading Sample ...')
sample_submission = pd.read_csv('../input/sample_submission.csv', low_memory=False)
# Out:
# Loading Properties...
# Loading Train...
# Loading Sample ...

# %%
def add_date_features(df):
    df["transaction_year"] = df["transactiondate"].dt.year
    df["transaction_month"] = df["transactiondate"].dt.month
    df["transaction_day"] = df["transactiondate"].dt.day
    df["transaction_quarter"] = df["transactiondate"].dt.quarter
    df.drop(["transactiondate"], inplace=True, axis=1)
    return df

# %% [markdown]
# ## 0.2 Сургалт болон шалгалтын өгөгдлөө бэлтгэх

# %%
train2016 = add_date_features(train2016)
train2017 = add_date_features(train2017)

sample_submission['parcelid'] = sample_submission['ParcelId']

print('Merge Train & Test with Properties...')
train2016 = pd.merge(train2016, properties2016, how='left', on='parcelid')
train2017 = pd.merge(train2017, properties2017, how='left', on='parcelid')
test_df = pd.merge(sample_submission, properties2016, how='left', on='parcelid')

print('Concat Train 2016 & 2017...')
train_df = pd.concat([train2016, train2017], axis=0)

del properties2016, properties2017, train2016, train2017
gc.collect();

print("Train: ", train_df.shape)
print("Test: ", test_df.shape)
# Out:
# Merge Train & Test with Properties...
# Concat Train 2016 & 2017...
# Train:  (167888, 63)
# Test:  (2985217, 65)

# %% [markdown]
# # 1. Сургалтанд ашиглах шинжүүдийг сонгох

# %%
# print ("Replacing NaN values by -999 !!")
# train_df.fillna(-999, inplace=True)
# test_df.fillna(-999, inplace=True)

# %%
# print(train_df['hashottuborspa'])
# for c in train_df.columns:
#     if c not in ['parcelid', 'logerror']:
#         print(c)
#         print(sum(np.isnan(train_df[c])), len(train_df[c]))
#         #plt.plot(train_df[c][np.isfinite(train_df[c])], train_df['logerror'], marker='o', linestyle = 'None',)
# #         plt.scatter(train_df['logerror'], train_df[c][np.isfinite(train_df[c])])
# #         plt.ylabel(c)
# #         plt.xlabel('logerror')
# #         plt.show()

# %% [markdown]
# ## 1.1a Бараг хоосон багануудыг хасах

# %%
# 98% нь хоосон бол хасна
missing_perc_thresh = 0.98
exclude_missing = []
num_rows = train_df.shape[0]
for c in train_df.columns:
    num_missing = train_df[c].isnull().sum()
    if num_missing == 0:
        continue
    missing_frac = num_missing / float(num_rows)
    if missing_frac > missing_perc_thresh:
        exclude_missing.append(c)
print("We exclude: %s" % exclude_missing)
print(len(exclude_missing))
# Out:
# We exclude: ['architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 'finishedsquarefeet13', 'finishedsquarefeet6', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'storytypeid', 'typeconstructiontypeid', 'yardbuildingsqft26', 'fireplaceflag']
# 13

# %% [markdown]
# ## 1.1b Бүгд адилхан утгатай багануудыг хасах

# %%
exclude_unique = []
for c in train_df.columns:
    num_uniques = len(train_df[c].unique())
    if train_df[c].isnull().sum() != 0:
        num_uniques -= 1
    if num_uniques == 1:
        exclude_unique.append(c)
print("We exclude: %s" % exclude_unique)
print(len(exclude_unique))
# Out:
# We exclude: ['decktypeid', 'hashottuborspa', 'poolcnt', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'storytypeid', 'fireplaceflag', 'taxdelinquencyflag']
# 9

# %% [markdown]
# ## 1.2a Сургалтанд ашиглах шинжүүд буюу багануудыг сонгох

# %%
exclude_other = ['parcelid', 'logerror','propertyzoningdesc']
train_features = []
for c in train_df.columns:
    if c not in exclude_missing \
       and c not in exclude_other and c not in exclude_unique:
        train_features.append(c)
print("We use these for training: %s" % train_features)
print(len(train_features))
# Out:
# We use these for training: ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'finishedsquarefeet15', 'finishedsquarefeet50', 'fips', 'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet', 'propertycountylandusecode', 'propertylandusetypeid', 'rawcensustractandblock', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr', 'unitcnt', 'yardbuildingsqft17', 'yearbuilt', 'numberofstories', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt', 'taxamount', 'taxdelinquencyyear', 'censustractandblock']
# 43

# %% [markdown]
# ## 1.2b Ангилах боломжтой шинжүүд

# %%
cat_feature_inds = []
cat_unique_thresh = 1000
for i, c in enumerate(train_features):
    num_uniques = len(train_df[c].unique())
    if num_uniques < cat_unique_thresh \
       and not 'sqft' in c \
       and not 'cnt' in c \
       and not 'nbr' in c \
       and not 'number' in c:
        cat_feature_inds.append(i)
        
print("Cat features are: %s" % [train_features[ind] for ind in cat_feature_inds])
# Out:
# Cat features are: ['transaction_year', 'transaction_month', 'transaction_day', 'transaction_quarter', 'airconditioningtypeid', 'buildingqualitytypeid', 'fips', 'heatingorsystemtypeid', 'propertycountylandusecode', 'propertylandusetypeid', 'regionidcity', 'regionidcounty', 'regionidneighborhood', 'regionidzip', 'yearbuilt', 'assessmentyear', 'taxdelinquencyyear']

# %% [markdown]
# ## 1.3 Хоосон утгуудыг бөглөх

# %%
print ("Replacing NaN values by -999 !!")
train_df.fillna(-999, inplace=True)
test_df.fillna(-999, inplace=True)
# Out:
# Replacing NaN values by -999 !!

# %% [markdown]
# # 2 Сургалт

# %%
def print_feature_importance(model, pool, X_train):
    feature_importances = model.get_feature_importance(pool)
    feature_names = X_train.columns
    for score, name in sorted(zip(feature_importances, feature_names), reverse=True):
        print('{}\t{}'.format(name, score))

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df[train_features], train_df.logerror, test_size=0.2, random_state=99)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

all_pool = Pool(train_df[train_features], train_df.logerror, cat_feature_inds)
train_pool = Pool(X_train, y_train, cat_feature_inds)
test_pool = Pool(X_test, y_test, cat_feature_inds)
# Out:
# (134310, 43) (134310,)
# (33578, 43) (33578,)

# %%
catboost_parameters = {
    'iterations': 400,
    'learning_rate': 0.035,
    'depth': 7,
    'verbose': 20,
#     'l2_leaf_reg': 1000,
    'task_type': 'GPU',
    'loss_function': 'MAE',
    'eval_metric': 'MAE',
    'random_seed': 0,
}

# %% [markdown]
# ## 2.1a Энигийн CatBoostRegressor

# %%
model = CatBoostRegressor(**catboost_parameters)
model.fit(train_pool, eval_set=test_pool)
# Out:
# 0:	learn: 0.0685970	test: 0.0699163	best: 0.0699163 (0)	total: 38.3ms	remaining: 15.3s
# 20:	learn: 0.0677143	test: 0.0691734	best: 0.0691724 (19)	total: 904ms	remaining: 16.3s
# 40:	learn: 0.0674822	test: 0.0691351	best: 0.0691332 (39)	total: 1.73s	remaining: 15.1s
# 60:	learn: 0.0672751	test: 0.0690890	best: 0.0690864 (59)	total: 2.53s	remaining: 14s
# 80:	learn: 0.0671101	test: 0.0690606	best: 0.0690606 (80)	total: 3.31s	remaining: 13s
# 100:	learn: 0.0669791	test: 0.0690428	best: 0.0690409 (96)	total: 4.19s	remaining: 12.4s
# 120:	learn: 0.0668344	test: 0.0690401	best: 0.0690401 (120)	total: 5.01s	remaining: 11.5s
# 140:	learn: 0.0666984	test: 0.0690549	best: 0.0690401 (120)	total: 5.81s	remaining: 10.7s
# 160:	learn: 0.0665935	test: 0.0690562	best: 0.0690401 (120)	total: 6.59s	remaining: 9.79s
# 180:	learn: 0.0664827	test: 0.0690363	best: 0.0690363 (180)	total: 7.4s	remaining: 8.95s
# 200:	learn: 0.0663762	test: 0.0690351	best: 0.0690342 (194)	total: 8.2s	remaining: 8.11s
# 220:	learn: 0.0662399	test: 0.0690364	best: 0.0690342 (217)	total: 8.96s	remaining: 7.26s
# 240:	learn: 0.0661291	test: 0.0690370	best: 0.0690342 (217)	total: 9.75s	remaining: 6.43s
# 260:	learn: 0.0660326	test: 0.0690336	best: 0.0690311 (258)	total: 10.5s	remaining: 5.61s
# 280:	learn: 0.0659229	test: 0.0690336	best: 0.0690282 (274)	total: 11.3s	remaining: 4.79s
# 300:	learn: 0.0658307	test: 0.0690345	best: 0.0690282 (274)	total: 12.1s	remaining: 3.97s
# 320:	learn: 0.0657314	test: 0.0690362	best: 0.0690282 (274)	total: 12.9s	remaining: 3.17s
# 340:	learn: 0.0656500	test: 0.0690427	best: 0.0690282 (274)	total: 13.7s	remaining: 2.37s
# 360:	learn: 0.0655299	test: 0.0690445	best: 0.0690282 (274)	total: 14.6s	remaining: 1.58s
# 380:	learn: 0.0654375	test: 0.0690492	best: 0.0690282 (274)	total: 15.3s	remaining: 765ms
# 399:	learn: 0.0653391	test: 0.0690596	best: 0.0690282 (274)	total: 16.1s	remaining: 0us
# bestTest = 0.06902815512
# bestIteration = 274
# Shrink model to first 275 iterations.

# %%
print_feature_importance(model, train_pool, X_train)
# Out:
# regionidzip	7.724040631830069
# yearbuilt	6.398873905798383
# transaction_month	6.0486148783697855
# finishedsquarefeet12	5.887595345735547
# propertycountylandusecode	5.366697273336976
# transaction_day	5.1986531767461015
# regionidcity	5.1939020286442545
# taxamount	4.722268908410884
# regionidneighborhood	4.259706820111791
# calculatedfinishedsquarefeet	3.7029941653460443
# lotsizesquarefeet	3.6740485135729957
# latitude	2.6329125494010617
# structuretaxvaluedollarcnt	2.5889561539003307
# propertylandusetypeid	2.5846271892814894
# heatingorsystemtypeid	2.5550813763448494
# transaction_quarter	2.501783396865115
# buildingqualitytypeid	2.4521815972559797
# taxvaluedollarcnt	2.4343941689869077
# landtaxvaluedollarcnt	2.3977922113805183
# longitude	2.39727912674393
# assessmentyear	1.903621303438252
# censustractandblock	1.8124729004581803
# taxdelinquencyyear	1.7388974023329575
# rawcensustractandblock	1.407794902449785
# airconditioningtypeid	1.3714343119841792
# transaction_year	1.3525987989624466
# bedroomcnt	1.2370149042560297
# fips	1.0782391437466858
# garagetotalsqft	0.8868401558345747
# regionidcounty	0.8134081016004584
# bathroomcnt	0.7894837099266129
# calculatedbathnbr	0.639344197628245
# fullbathcnt	0.6352801725341614
# yardbuildingsqft17	0.5676997424496096
# finishedsquarefeet15	0.5225301890288223
# finishedsquarefeet50	0.49428865828191604
# garagecarcnt	0.4627726612945534
# numberofstories	0.45455484760410164
# unitcnt	0.4129069602395822
# fireplacecnt	0.2763149441019528
# finishedfloor1squarefeet	0.24590752914757544
# roomcnt	0.1614376773173469
# threequarterbathnbr	0.012753367318971634

# %%
# submission = pd.DataFrame({
#     'ParcelId': test_df['parcelid'],
# })

# test_dates = {
#     '201610': pd.Timestamp('2016-09-30'),
#     '201611': pd.Timestamp('2016-10-31'),
#     '201612': pd.Timestamp('2016-11-30'),
#     '201710': pd.Timestamp('2017-09-30'),
#     '201711': pd.Timestamp('2017-10-31'),
#     '201712': pd.Timestamp('2017-11-30')
# }

# for label, test_date in test_dates.items():
#     print("Predicting for: %s ... " % (label))
#     test_df['transactiondate'] = test_date
#     test_df = add_date_features(test_df)
#     y_pred = model.predict(test_df[train_features])
#     submission[label] = y_pred

# submission_major = 1
# print("Creating submission: submission_%03d.csv ..." % (submission_major))
# submission.to_csv(
#     'submission_%03d.csv' % (submission_major),
#     float_format='%.4f',
#     index=False)
# print("Finished.")

# %% [markdown]
# ## 2.1b Ensemble - CatBoostRegressor

# %%
num_ensembles = 5
# ensemble models
models = [None] * num_ensembles
for i in range(num_ensembles):
    print("\nTraining (ensemble): %d ..." % (i))
    catboost_parameters['random_seed'] = i
    models[i] = CatBoostRegressor(**catboost_parameters)
    models[i].fit(train_pool, eval_set=test_pool)
    print('-- Feature Importance --')
    print_feature_importance(models[i], train_pool, X_train)
# Out:
# Training (ensemble): 0 ...
# 0:	learn: 0.0685969	test: 0.0699163	best: 0.0699163 (0)	total: 33.1ms	remaining: 13.2s
# 20:	learn: 0.0677143	test: 0.0691734	best: 0.0691724 (19)	total: 851ms	remaining: 15.4s
# 40:	learn: 0.0674822	test: 0.0691351	best: 0.0691332 (39)	total: 1.63s	remaining: 14.3s
# 60:	learn: 0.0672751	test: 0.0690890	best: 0.0690863 (59)	total: 2.44s	remaining: 13.6s
# 80:	learn: 0.0671101	test: 0.0690606	best: 0.0690606 (80)	total: 3.25s	remaining: 12.8s
# 100:	learn: 0.0669791	test: 0.0690428	best: 0.0690408 (96)	total: 4.11s	remaining: 12.2s
# 120:	learn: 0.0668344	test: 0.0690401	best: 0.0690401 (120)	total: 4.93s	remaining: 11.4s
# 140:	learn: 0.0666984	test: 0.0690549	best: 0.0690401 (120)	total: 5.75s	remaining: 10.6s
# 160:	learn: 0.0665935	test: 0.0690562	best: 0.0690401 (120)	total: 6.55s	remaining: 9.72s
# 180:	learn: 0.0664827	test: 0.0690363	best: 0.0690363 (180)	total: 7.35s	remaining: 8.89s
# 200:	learn: 0.0663761	test: 0.0690351	best: 0.0690342 (194)	total: 8.13s	remaining: 8.05s
# 220:	learn: 0.0662399	test: 0.0690364	best: 0.0690342 (194)	total: 8.89s	remaining: 7.2s
# 240:	learn: 0.0661291	test: 0.0690370	best: 0.0690342 (194)	total: 9.68s	remaining: 6.38s
# 260:	learn: 0.0660326	test: 0.0690336	best: 0.0690311 (258)	total: 10.5s	remaining: 5.57s
# 280:	learn: 0.0659229	test: 0.0690336	best: 0.0690282 (274)	total: 11.2s	remaining: 4.76s
# 300:	learn: 0.0658307	test: 0.0690345	best: 0.0690282 (274)	total: 12s	remaining: 3.95s
# 320:	learn: 0.0657314	test: 0.0690362	best: 0.0690282 (274)	total: 12.8s	remaining: 3.15s
# 340:	learn: 0.0656500	test: 0.0690427	best: 0.0690282 (274)	total: 13.6s	remaining: 2.36s
# 360:	learn: 0.0655299	test: 0.0690445	best: 0.0690282 (274)	total: 14.5s	remaining: 1.56s
# 380:	learn: 0.0654375	test: 0.0690492	best: 0.0690282 (274)	total: 15.2s	remaining: 760ms
# 399:	learn: 0.0653391	test: 0.0690596	best: 0.0690282 (274)	total: 16s	remaining: 0us
# bestTest = 0.06902816239
# bestIteration = 274
# Shrink model to first 275 iterations.
# -- Feature Importance --
# regionidzip	7.724040631830069
# yearbuilt	6.398873905798383
# transaction_month	6.0486148783697855
# finishedsquarefeet12	5.887595345735547
# propertycountylandusecode	5.366697273336976
# transaction_day	5.1986531767461015
# regionidcity	5.1939020286442545
# taxamount	4.722268908410884
# regionidneighborhood	4.259706820111791
# calculatedfinishedsquarefeet	3.7029941653460443
# lotsizesquarefeet	3.6740485135729957
# latitude	2.6329125494010617
# structuretaxvaluedollarcnt	2.5889561539003307
# propertylandusetypeid	2.5846271892814894
# heatingorsystemtypeid	2.5550813763448494
# transaction_quarter	2.501783396865115
# buildingqualitytypeid	2.4521815972559797
# taxvaluedollarcnt	2.4343941689869077
# landtaxvaluedollarcnt	2.3977922113805183
# longitude	2.39727912674393
# assessmentyear	1.903621303438252
# censustractandblock	1.8124729004581803
# taxdelinquencyyear	1.7388974023329575
# rawcensustractandblock	1.407794902449785
# airconditioningtypeid	1.3714343119841792
# transaction_year	1.3525987989624466
# bedroomcnt	1.2370149042560297
# fips	1.0782391437466858
# garagetotalsqft	0.8868401558345747
# regionidcounty	0.8134081016004584
# bathroomcnt	0.7894837099266129
# calculatedbathnbr	0.639344197628245
# fullbathcnt	0.6352801725341614
# yardbuildingsqft17	0.5676997424496096
# finishedsquarefeet15	0.5225301890288223
# finishedsquarefeet50	0.49428865828191604
# garagecarcnt	0.4627726612945534
# numberofstories	0.45455484760410164
# unitcnt	0.4129069602395822
# fireplacecnt	0.2763149441019528
# finishedfloor1squarefeet	0.24590752914757544
# roomcnt	0.1614376773173469
# threequarterbathnbr	0.012753367318971634
#
# Training (ensemble): 1 ...
# 0:	learn: 0.0685715	test: 0.0698651	best: 0.0698651 (0)	total: 46.2ms	remaining: 18.4s
# 20:	learn: 0.0677501	test: 0.0692243	best: 0.0692243 (20)	total: 863ms	remaining: 15.6s
# 40:	learn: 0.0675054	test: 0.0691391	best: 0.0691391 (40)	total: 1.66s	remaining: 14.5s
# 60:	learn: 0.0673263	test: 0.0691002	best: 0.0691002 (60)	total: 2.48s	remaining: 13.8s
# 80:	learn: 0.0671654	test: 0.0690879	best: 0.0690879 (80)	total: 3.36s	remaining: 13.2s
# 100:	learn: 0.0669997	test: 0.0690522	best: 0.0690482 (97)	total: 4.17s	remaining: 12.4s
# 120:	learn: 0.0668463	test: 0.0690455	best: 0.0690432 (108)	total: 4.96s	remaining: 11.4s
# 140:	learn: 0.0667251	test: 0.0690521	best: 0.0690426 (121)	total: 5.73s	remaining: 10.5s
# 160:	learn: 0.0665757	test: 0.0690346	best: 0.0690345 (159)	total: 6.54s	remaining: 9.71s
# 180:	learn: 0.0664543	test: 0.0690406	best: 0.0690336 (162)	total: 7.32s	remaining: 8.85s
# 200:	learn: 0.0663267	test: 0.0690436	best: 0.0690336 (162)	total: 8.09s	remaining: 8.01s
# 220:	learn: 0.0662024	test: 0.0690473	best: 0.0690336 (162)	total: 8.89s	remaining: 7.2s
# 240:	learn: 0.0661170	test: 0.0690468	best: 0.0690336 (162)	total: 9.7s	remaining: 6.4s
# 260:	learn: 0.0660180	test: 0.0690673	best: 0.0690336 (162)	total: 10.5s	remaining: 5.59s
# 280:	learn: 0.0659146	test: 0.0690648	best: 0.0690336 (162)	total: 11.3s	remaining: 4.78s
# 300:	learn: 0.0658239	test: 0.0690677	best: 0.0690336 (162)	total: 12.1s	remaining: 3.97s
# 320:	learn: 0.0657278	test: 0.0690739	best: 0.0690336 (162)	total: 12.9s	remaining: 3.17s
# 340:	learn: 0.0656251	test: 0.0690705	best: 0.0690336 (162)	total: 13.8s	remaining: 2.38s
# 360:	learn: 0.0655205	test: 0.0690646	best: 0.0690336 (162)	total: 14.6s	remaining: 1.57s
# 380:	learn: 0.0654121	test: 0.0690683	best: 0.0690336 (162)	total: 15.3s	remaining: 765ms
# 399:	learn: 0.0653142	test: 0.0690826	best: 0.0690336 (162)	total: 16.1s	remaining: 0us
# bestTest = 0.06903355736
# bestIteration = 162
# Shrink model to first 163 iterations.
# -- Feature Importance --
# regionidzip	9.254206772515182
# finishedsquarefeet12	6.6851598865504975
# transaction_month	6.398501139303524
# taxamount	5.164349108553113
# yearbuilt	5.09897008019376
# propertycountylandusecode	4.972379630767673
# regionidneighborhood	4.831804427410112
# regionidcity	4.443279185284289
# calculatedfinishedsquarefeet	4.094134054847346
# lotsizesquarefeet	3.7223953064850455
# structuretaxvaluedollarcnt	3.140155813382397
# propertylandusetypeid	3.0937405212944373
# latitude	2.939638046018679
# transaction_day	2.8832203673859462
# taxvaluedollarcnt	2.8788780857176914
# taxdelinquencyyear	2.619528050049268
# buildingqualitytypeid	2.3662265286100315
# heatingorsystemtypeid	2.3270503171546943
# longitude	1.9330153166638144
# rawcensustractandblock	1.8328424287447194
# transaction_quarter	1.8222988678739993
# regionidcounty	1.8043564455616397
# airconditioningtypeid	1.5846843956807022
# bedroomcnt	1.4895847503381607
# fips	1.4242744451044833
# landtaxvaluedollarcnt	1.3830053784070404
# censustractandblock	1.3781327508509293
# bathroomcnt	1.0726485798123782
# assessmentyear	1.0319160247591341
# fullbathcnt	0.8849053052981986
# transaction_year	0.8016484702112658
# garagetotalsqft	0.7067663587129605
# yardbuildingsqft17	0.6984892703515837
# unitcnt	0.5925007392170529
# calculatedbathnbr	0.5715063471308652
# finishedsquarefeet15	0.4692500130743426
# numberofstories	0.4105030157160524
# fireplacecnt	0.3406332622174332
# garagecarcnt	0.33373287935378465
# finishedfloor1squarefeet	0.17603285823521447
# finishedsquarefeet50	0.16443440373793788
# roomcnt	0.09534165043004166
# threequarterbathnbr	0.0838787209925785
#
# Training (ensemble): 2 ...
# 0:	learn: 0.0685942	test: 0.0699073	best: 0.0699073 (0)	total: 37.3ms	remaining: 14.9s
# 20:	learn: 0.0677357	test: 0.0692057	best: 0.0692049 (19)	total: 864ms	remaining: 15.6s
# 40:	learn: 0.0674944	test: 0.0691497	best: 0.0691465 (39)	total: 1.67s	remaining: 14.6s
# 60:	learn: 0.0673021	test: 0.0691109	best: 0.0691109 (60)	total: 2.47s	remaining: 13.7s
# 80:	learn: 0.0671509	test: 0.0690905	best: 0.0690905 (80)	total: 3.31s	remaining: 13.1s
# 100:	learn: 0.0670305	test: 0.0690748	best: 0.0690748 (100)	total: 4.16s	remaining: 12.3s
# 120:	learn: 0.0668824	test: 0.0690632	best: 0.0690632 (120)	total: 5s	remaining: 11.5s
# 140:	learn: 0.0667657	test: 0.0690521	best: 0.0690521 (140)	total: 5.77s	remaining: 10.6s
# 160:	learn: 0.0666237	test: 0.0690440	best: 0.0690430 (157)	total: 6.59s	remaining: 9.78s
# 180:	learn: 0.0664961	test: 0.0690333	best: 0.0690270 (170)	total: 7.4s	remaining: 8.95s
# 200:	learn: 0.0663788	test: 0.0690237	best: 0.0690237 (200)	total: 8.22s	remaining: 8.14s
# 220:	learn: 0.0662765	test: 0.0690195	best: 0.0690195 (220)	total: 9.01s	remaining: 7.3s
# 240:	learn: 0.0661594	test: 0.0690172	best: 0.0690144 (229)	total: 9.81s	remaining: 6.47s
# 260:	learn: 0.0660685	test: 0.0690244	best: 0.0690144 (229)	total: 10.6s	remaining: 5.65s
# 280:	learn: 0.0659770	test: 0.0690173	best: 0.0690144 (229)	total: 11.4s	remaining: 4.83s
# 300:	learn: 0.0658566	test: 0.0690244	best: 0.0690144 (229)	total: 12.2s	remaining: 4.01s
# 320:	learn: 0.0657669	test: 0.0690236	best: 0.0690144 (229)	total: 13s	remaining: 3.19s
# 340:	learn: 0.0656634	test: 0.0690199	best: 0.0690144 (229)	total: 13.8s	remaining: 2.39s
# 360:	learn: 0.0655661	test: 0.0690263	best: 0.0690144 (229)	total: 14.6s	remaining: 1.58s
# 380:	learn: 0.0654790	test: 0.0690219	best: 0.0690144 (229)	total: 15.4s	remaining: 767ms
# 399:	learn: 0.0653765	test: 0.0690175	best: 0.0690144 (229)	total: 16.1s	remaining: 0us
# bestTest = 0.06901444957
# bestIteration = 229
# Shrink model to first 230 iterations.
# -- Feature Importance --
# regionidzip	8.063886679968006
# yearbuilt	6.51717381536685
# transaction_month	6.041485385239315
# propertycountylandusecode	5.92131873321449
# finishedsquarefeet12	5.428058563331382
# taxamount	4.943727668053863
# calculatedfinishedsquarefeet	4.805641761410162
# regionidcity	4.4599440782802855
# transaction_day	4.306310050441047
# regionidneighborhood	3.645344311308484
# landtaxvaluedollarcnt	3.524096742812613
# taxvaluedollarcnt	2.943193112444275
# propertylandusetypeid	2.8703253765186307
# lotsizesquarefeet	2.7891819051299445
# transaction_quarter	2.698586258459951
# latitude	2.613246541593384
# buildingqualitytypeid	2.571119255924279
# structuretaxvaluedollarcnt	2.340586158687883
# assessmentyear	2.3349011813365443
# censustractandblock	2.1918106293774393
# longitude	2.155081938973709
# rawcensustractandblock	1.841438031451802
# taxdelinquencyyear	1.802637028902276
# airconditioningtypeid	1.7065550437088965
# heatingorsystemtypeid	1.5178340361768454
# garagetotalsqft	0.9995697344387435
# fips	0.9808091570477171
# fullbathcnt	0.9615178236241094
# regionidcounty	0.9404001784678158
# transaction_year	0.9290611702454624
# bedroomcnt	0.8679794337766197
# calculatedbathnbr	0.5761037239274702
# unitcnt	0.5534745035768757
# garagecarcnt	0.47201499697094323
# bathroomcnt	0.4422430797166729
# fireplacecnt	0.4411741356157588
# yardbuildingsqft17	0.4114458580768257
# numberofstories	0.3909306077632613
# finishedsquarefeet50	0.30997671591205445
# finishedsquarefeet15	0.24462669462841385
# finishedfloor1squarefeet	0.2281108339360661
# roomcnt	0.13811343737287202
# threequarterbathnbr	0.07896362678994101
#
# Training (ensemble): 3 ...
# 0:	learn: 0.0686036	test: 0.0699056	best: 0.0699056 (0)	total: 42.3ms	remaining: 16.9s
# 20:	learn: 0.0677186	test: 0.0691919	best: 0.0691916 (19)	total: 874ms	remaining: 15.8s
# 40:	learn: 0.0674955	test: 0.0691320	best: 0.0691320 (40)	total: 1.67s	remaining: 14.6s
# 60:	learn: 0.0673175	test: 0.0691050	best: 0.0691043 (53)	total: 2.51s	remaining: 14s
# 80:	learn: 0.0671413	test: 0.0690986	best: 0.0690896 (68)	total: 3.37s	remaining: 13.3s
# 100:	learn: 0.0670357	test: 0.0690854	best: 0.0690851 (99)	total: 4.15s	remaining: 12.3s
# 120:	learn: 0.0669182	test: 0.0690676	best: 0.0690676 (120)	total: 4.95s	remaining: 11.4s
# 140:	learn: 0.0668022	test: 0.0690655	best: 0.0690643 (130)	total: 5.73s	remaining: 10.5s
# 160:	learn: 0.0666847	test: 0.0690454	best: 0.0690454 (160)	total: 6.56s	remaining: 9.73s
# 180:	learn: 0.0665403	test: 0.0690465	best: 0.0690437 (177)	total: 7.37s	remaining: 8.91s
# 200:	learn: 0.0664284	test: 0.0690436	best: 0.0690387 (188)	total: 8.13s	remaining: 8.05s
# 220:	learn: 0.0663128	test: 0.0690380	best: 0.0690378 (210)	total: 8.92s	remaining: 7.23s
# 240:	learn: 0.0662133	test: 0.0690389	best: 0.0690342 (224)	total: 9.71s	remaining: 6.41s
# 260:	learn: 0.0660992	test: 0.0690381	best: 0.0690342 (224)	total: 10.5s	remaining: 5.59s
# 280:	learn: 0.0660111	test: 0.0690367	best: 0.0690342 (224)	total: 11.3s	remaining: 4.79s
# 300:	learn: 0.0659309	test: 0.0690390	best: 0.0690342 (224)	total: 12.1s	remaining: 3.97s
# 320:	learn: 0.0658408	test: 0.0690402	best: 0.0690342 (224)	total: 12.9s	remaining: 3.18s
# 340:	learn: 0.0657536	test: 0.0690349	best: 0.0690342 (224)	total: 13.7s	remaining: 2.37s
# 360:	learn: 0.0656309	test: 0.0690428	best: 0.0690342 (224)	total: 14.5s	remaining: 1.57s
# 380:	learn: 0.0655247	test: 0.0690367	best: 0.0690342 (224)	total: 15.3s	remaining: 764ms
# 399:	learn: 0.0654353	test: 0.0690497	best: 0.0690342 (224)	total: 16.1s	remaining: 0us
# bestTest = 0.06903421901
# bestIteration = 224
# Shrink model to first 225 iterations.
# -- Feature Importance --
# regionidzip	8.339852543894409
# finishedsquarefeet12	6.509125941690221
# yearbuilt	6.228245128622764
# transaction_month	5.9068576163389315
# transaction_day	5.350333296368745
# propertycountylandusecode	4.890560173860071
# taxamount	4.868943991141277
# regionidcity	4.846943190544546
# calculatedfinishedsquarefeet	3.792496372547861
# regionidneighborhood	3.725961009427635
# propertylandusetypeid	3.4841812915054557
# latitude	3.1523273072099354
# lotsizesquarefeet	2.932984510759942
# landtaxvaluedollarcnt	2.846423180537043
# heatingorsystemtypeid	2.7068615744328897
# buildingqualitytypeid	2.6835504738123785
# longitude	2.325254591819783
# structuretaxvaluedollarcnt	2.2366910196695717
# taxvaluedollarcnt	2.2296110997137197
# transaction_quarter	1.9201944317504092
# assessmentyear	1.8909407556682527
# rawcensustractandblock	1.6379815535105209
# taxdelinquencyyear	1.5723073118417272
# bedroomcnt	1.5318869123922862
# censustractandblock	1.4579484684073765
# fullbathcnt	1.4364174838482588
# transaction_year	1.4182937613171112
# airconditioningtypeid	1.1808259977257634
# regionidcounty	0.988526701562622
# calculatedbathnbr	0.8278455172474516
# fips	0.8083774288849158
# garagetotalsqft	0.577801773769319
# yardbuildingsqft17	0.5661416353389842
# garagecarcnt	0.49548191943024017
# finishedsquarefeet50	0.48082693912634406
# bathroomcnt	0.4075890870188318
# fireplacecnt	0.40155423633904386
# finishedfloor1squarefeet	0.294435268949768
# unitcnt	0.28658773008733757
# roomcnt	0.2404769203657197
# finishedsquarefeet15	0.23081092581891155
# numberofstories	0.21064948899151667
# threequarterbathnbr	0.07889343671010365
#
# Training (ensemble): 4 ...
# 0:	learn: 0.0685762	test: 0.0698825	best: 0.0698825 (0)	total: 42.4ms	remaining: 16.9s
# 20:	learn: 0.0677420	test: 0.0692123	best: 0.0692123 (20)	total: 848ms	remaining: 15.3s
# 40:	learn: 0.0674813	test: 0.0691234	best: 0.0691234 (40)	total: 1.66s	remaining: 14.5s
# 60:	learn: 0.0672898	test: 0.0690938	best: 0.0690937 (59)	total: 2.48s	remaining: 13.8s
# 80:	learn: 0.0671339	test: 0.0690656	best: 0.0690652 (74)	total: 3.35s	remaining: 13.2s
# 100:	learn: 0.0669642	test: 0.0690443	best: 0.0690443 (100)	total: 4.15s	remaining: 12.3s
# 120:	learn: 0.0668393	test: 0.0690432	best: 0.0690386 (116)	total: 4.95s	remaining: 11.4s
# 140:	learn: 0.0667004	test: 0.0690326	best: 0.0690326 (140)	total: 5.77s	remaining: 10.6s
# 160:	learn: 0.0665809	test: 0.0690371	best: 0.0690275 (151)	total: 6.56s	remaining: 9.74s
# 180:	learn: 0.0664590	test: 0.0690382	best: 0.0690275 (151)	total: 7.37s	remaining: 8.92s
# 200:	learn: 0.0663646	test: 0.0690290	best: 0.0690275 (151)	total: 8.18s	remaining: 8.1s
# 220:	learn: 0.0662626	test: 0.0690237	best: 0.0690234 (214)	total: 9.02s	remaining: 7.31s
# 240:	learn: 0.0661542	test: 0.0690162	best: 0.0690159 (239)	total: 9.87s	remaining: 6.51s
# 260:	learn: 0.0660396	test: 0.0690204	best: 0.0690158 (245)	total: 10.6s	remaining: 5.66s
# 280:	learn: 0.0659286	test: 0.0690271	best: 0.0690158 (245)	total: 11.4s	remaining: 4.84s
# 300:	learn: 0.0658292	test: 0.0690324	best: 0.0690158 (245)	total: 12.2s	remaining: 4.01s
# 320:	learn: 0.0657387	test: 0.0690345	best: 0.0690158 (245)	total: 13s	remaining: 3.2s
# 340:	learn: 0.0656515	test: 0.0690312	best: 0.0690158 (245)	total: 13.8s	remaining: 2.39s
# 360:	learn: 0.0655485	test: 0.0690394	best: 0.0690158 (245)	total: 14.6s	remaining: 1.57s
# 380:	learn: 0.0654466	test: 0.0690469	best: 0.0690158 (245)	total: 15.4s	remaining: 768ms
# 399:	learn: 0.0653558	test: 0.0690593	best: 0.0690158 (245)	total: 16.2s	remaining: 0us
# bestTest = 0.06901577286
# bestIteration = 245
# Shrink model to first 246 iterations.
# -- Feature Importance --
# regionidzip	8.39386656011339
# finishedsquarefeet12	6.35546340850551
# propertycountylandusecode	6.066622196180384
# yearbuilt	5.867762179585989
# taxamount	5.7547737797972305
# transaction_month	5.110598287703801
# regionidcity	4.737249157797609
# calculatedfinishedsquarefeet	4.6126404646746675
# regionidneighborhood	4.586053821514679
# transaction_day	4.42314543235734
# lotsizesquarefeet	4.1793882056912555
# propertylandusetypeid	3.1932159069082493
# latitude	2.9104832753676066
# buildingqualitytypeid	2.6412076628437395
# landtaxvaluedollarcnt	2.5332441174760896
# structuretaxvaluedollarcnt	2.4488546484378584
# transaction_quarter	2.4359747021635965
# assessmentyear	2.1161312663929888
# heatingorsystemtypeid	1.9354944043652171
# taxvaluedollarcnt	1.679488398568414
# taxdelinquencyyear	1.6733343305531205
# censustractandblock	1.5843791595625167
# longitude	1.5666988512773052
# airconditioningtypeid	1.4708718356524966
# bedroomcnt	1.1742713765736137
# rawcensustractandblock	1.1563504306643415
# transaction_year	1.1253268811289225
# fullbathcnt	1.0885180529127
# calculatedbathnbr	1.074149776203595
# regionidcounty	0.908113574413628
# fips	0.8510834100578442
# garagetotalsqft	0.7461400687582469
# yardbuildingsqft17	0.5626381995572588
# fireplacecnt	0.5614656040372799
# finishedsquarefeet15	0.491516574920108
# numberofstories	0.48057988754230824
# roomcnt	0.320186070628845
# bathroomcnt	0.28840441737944933
# unitcnt	0.24863890430221638
# finishedfloor1squarefeet	0.2026604728498478
# finishedsquarefeet50	0.1733039448694318
# garagecarcnt	0.14498074511842118
# threequarterbathnbr	0.1247295545908947

# %%
submission = pd.DataFrame({
    'ParcelId': test_df['parcelid'],
})

test_dates = {
    '201610': pd.Timestamp('2016-09-30'),
    '201611': pd.Timestamp('2016-10-31'),
    '201612': pd.Timestamp('2016-11-30'),
    '201710': pd.Timestamp('2017-09-30'),
    '201711': pd.Timestamp('2017-10-31'),
    '201712': pd.Timestamp('2017-11-30')
}

for label, test_date in test_dates.items():
    print("Predicting for: %s ... " % (label))
    test_df['transactiondate'] = test_date
    test_df = add_date_features(test_df)
    y_pred = 0.0
    for i in range(num_ensembles):
        print("Ensemble:", i)
        y_pred += models[i].predict(test_df[train_features])
    y_pred /= num_ensembles
    submission[label] = y_pred

submission_major = 2
print("Creating submission: submission_%03d.csv ..." % (submission_major))
submission.to_csv(
    'submission_%03d.csv' % (submission_major),
    float_format='%.4f',
    index=False)
print("Finished.")
# Out:
# Predicting for: 201610 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Predicting for: 201611 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Predicting for: 201612 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Predicting for: 201710 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Predicting for: 201711 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Predicting for: 201712 ...
# Ensemble: 0
# Ensemble: 1
# Ensemble: 2
# Ensemble: 3
# Ensemble: 4
# Creating submission: submission_002.csv ...
# Finished.
