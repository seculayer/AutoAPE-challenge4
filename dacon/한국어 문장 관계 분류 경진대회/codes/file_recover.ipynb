# %%
import os
os.getcwd()
# Out:
# '/home/centos/.local/share/Trash/files'

# %%
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'Untitled 1.ipynb',
#  'Untitled1.ipynb',
#  'Untitled 2.ipynb',
#  'Hotel recommendation2.py',
#  'Untitled 3.ipynb',
#  'code_x_ray2.py',
#  'Fold_1.csv',
#  'Fold_2.csv',
#  'Fold_3.csv',
#  'Fold_4.csv',
#  'Fold_1 1.csv',
#  'Fold_2 1.csv',
#  'Fold_3 1.csv',
#  'Fold_4 1.csv',
#  'Fold_5.csv',
#  'submission_Random_Forest.csv',
#  'sample_submission.csv',
#  'submission.csv',
#  'Hotel_Recommendation tutorial.ipynb',
#  'sample_submission 1.csv',
#  '2-cls test pred.csv',
#  'submission_postprocessed.csv',
#  'Untitled 4.ipynb',
#  'santa.ipynb',
#  'code_x_ray.py',
#  'test.py',
#  'vbg_lib',
#  'omegaconf',
#  'timm-efficientdet-pytorch',
#  'omegaconf 1',
#  'timm-efficientdet-pytorch 1',
#  'Untitled 5.ipynb',
#  'XSS_ape_log_dup.csv',
#  'HR RNFO.ipynb',
#  'XSS_ape_log_dup 1.csv',
#  'baseline.csv',
#  'code_ld.py',
#  'data',
#  'dataset.ipynb',
#  'model_effdet.ipynb',
#  'visualize.ipynb',
#  'utils.ipynb',
#  'code_pfs.py',
# ...

# %%
cd ..
# Out:
# /home/centos/.local/share/Trash/files

# %%
cd kakao_klue_roberta_clean 7
# Out:
# /home/centos/.local/share/Trash/files/kakao_klue_roberta_clean 7

# %%
ls
# Out:
# runs/

# %%
cd /home/$USER/.local/share/Trash/files
# Out:
# [Errno 2] No such file or directory: '/home/$USER/.local/share/Trash/files'
# /

# %%
ls
# Out:
# checkpoint-500/  runs/

# %%
cd ko_electra_concat.ipynb
# Out:
# [Errno 20] Not a directory: 'ko_electra_concat.ipynb'
# /home/centos/.local/share/Trash/files

# %%
ko_electra_concat.ipynb
ko_electra.ipynb

# %%
# !mv runs /home/centos/psw/KSRC/Trash
