# %% [markdown]
# ##
#
#
#
#
#
#
#
# #### :
#
#
# ## Content
#
# >
# >
# >
#
# ```
# def prepare_input(cfg, text, text_2=None):
#     inputs = cfg.tokenizer(text, text_2,
#                            padding="max_length",
#                            add_special_tokens=True,
#                            max_length=cfg.max_len,
#                            truncation=True)
#
#     [...]
#
# def inference_fn(test_loader, model, device):
#     preds = []
#     model.eval()
#     model.to(device)
#     tk0 = tqdm(test_loader, total=len(test_loader))
#
#     for inputs in tk0:
#         for k, v in inputs.items():
#             inputs[k] = v.to(device)
#
#         with torch.no_grad():
#             output = model(inputs)
#
#     [...]
# ```

# %% [markdown]
# # 1. Import & Def & Set & Load

# %%
import gc
import os
import pickle
import glob

from text_unidecode import unidecode
from typing import Dict, List, Tuple
import codecs

import numpy as np
import pandas as pd

from tqdm import tqdm

import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.nn import Parameter
from torch.utils.data import Dataset, DataLoader

from transformers import AutoModel, AutoTokenizer, AutoConfig

import warnings
warnings.simplefilter('ignore')

# %%
def replace_encoding_with_utf8(error: UnicodeError) -> Tuple[bytes, int]:
    return error.object[error.start : error.end].encode("utf-8"), error.end


def replace_decoding_with_cp1252(error: UnicodeError) -> Tuple[str, int]:
    return error.object[error.start : error.end].decode("cp1252"), error.end

codecs.register_error("replace_encoding_with_utf8", replace_encoding_with_utf8)
codecs.register_error("replace_decoding_with_cp1252", replace_decoding_with_cp1252)


def resolve_encodings_and_normalize(text: str) -> str:
    text = (
        text.encode("raw_unicode_escape")
        .decode("utf-8", errors="replace_decoding_with_cp1252")
        .encode("cp1252", errors="replace_encoding_with_utf8")
        .decode("utf-8", errors="replace_decoding_with_cp1252")
    )
    
    text = unidecode(text)
    
    return text


def fetch_essay(essay_id: str, txt_dir: str):
    essay_path = os.path.join(COMP_DIR + txt_dir, essay_id + '.txt')
    essay_text = open(essay_path, 'r').read()
    
    return essay_text


def prepare_input(cfg, text, text_2=None):
    inputs = cfg.tokenizer(text, text_2,
                           padding="max_length",
                           add_special_tokens=True,
                           max_length=cfg.max_len,
                           truncation=True)

    for k, v in inputs.items():
        inputs[k] = torch.tensor(v, dtype=torch.long)
        
    return inputs


def inference_fn(test_loader, model, device):
    preds = []
    model.eval()
    model.to(device)
    tk0 = tqdm(test_loader, total=len(test_loader))
    
    for inputs in tk0:
        for k, v in inputs.items():
            inputs[k] = v.to(device)
            
        with torch.no_grad():
            output = model(inputs)
        
        preds.append(F.softmax(output).to('cpu').numpy())

    return np.concatenate(preds)  


def show_gradient(df, n_row=None):
    if not n_row:
        n_row = 5

    return df.head(n_row) \
                .assign(all_mean=lambda x: x.mean(axis=1)) \
                    .style.background_gradient(cmap=cm, axis=1)

# %%
pd.set_option('display.precision', 4)
cm = sns.light_palette('green', as_cmap=True)
props_param = "color:white; font-weight:bold; background-color:green;"

N_ROW = 10

COMP_DIR = "../input/feedback-prize-effectiveness/"
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
test_path = COMP_DIR + "test.csv"
submission_path = COMP_DIR + "sample_submission.csv"

test_origin = pd.read_csv(test_path)
submission_origin = pd.read_csv(submission_path)

# %%
test_origin.head()
# Out:
#    discourse_id      essay_id  \
# 0  a261b6e14276  D72CB1C11673
# 1  5a88900e7dc1  D72CB1C11673
# 2  9790d835736b  D72CB1C11673
# 3  75ce6d68b67b  D72CB1C11673
# 4  93578d946723  D72CB1C11673
#
#                                       discourse_text discourse_type
# 0  Making choices in life can be very difficult. ...           Lead
# 1  Seeking multiple opinions can help a person ma...       Position
# 2                     it can decrease stress levels           Claim
# 3             a great chance to learn something new           Claim
# 4               can be very helpful and beneficial.           Claim

# %% [markdown]
# # 2. Check unidecode(text)
#
# ```
# def resolve_encodings_and_normalize(text: str) -> str:
#     text = (
#         text.encode("raw_unicode_escape")
#         .decode("utf-8", errors="replace_decoding_with_cp1252")
#         .encode("cp1252", errors="replace_encoding_with_utf8")
#         .decode("utf-8", errors="replace_decoding_with_cp1252")
#     )
#
#     text = unidecode(text)
# ```

# %%
data_path = "../input/feedback-prize-effectiveness/train.csv"
cols_list = ['essay_id', 'discourse_text']
idxs_list = [49, 80, 945, 947, 1870]

temp = pd.read_csv(data_path, usecols=cols_list).loc[idxs_list, :]
temp
# Out:
#           essay_id                                     discourse_text
# 49    0158970BC5D2  Often times throughout middle school, my teach...
# 80    01AFC67DF935  President Obama has done nothing to improve ou...
# 945   11B9AC1814C8  The article says, ¨... humans have sent numero...
# 947   11B9AC1814C8  However, the article says that this can only g...
# 1870  22E8627A3CB9  Many people are able to tell when a peer is an...

# %%
temp['discourse_text_UPD'] = temp['discourse_text'].apply(resolve_encodings_and_normalize)

temp['essay_text'] = temp['essay_id'].transform(fetch_essay, txt_dir='train')
temp['essay_text_UPD'] = temp['essay_text'].apply(resolve_encodings_and_normalize)

temp
# Out:
#           essay_id                                     discourse_text  \
# 49    0158970BC5D2  Often times throughout middle school, my teach...
# 80    01AFC67DF935  President Obama has done nothing to improve ou...
# 945   11B9AC1814C8  The article says, ¨... humans have sent numero...
# 947   11B9AC1814C8  However, the article says that this can only g...
# 1870  22E8627A3CB9  Many people are able to tell when a peer is an...
#
#                                      discourse_text_UPD  \
# 49    Often times throughout middle school, my teach...
# 80    President Obama has done nothing to improve ou...
# 945   The article says, "... humans have sent numero...
# 947   However, the article says that this can only g...
# 1870  Many people are able to tell when a peer is an...
#
#                                              essay_text  \
# 49    Students around the world are forgetting more ...
# 80    President Obama has done nothing to improve ou...
# 945   People have studied the many planets in our so...
# 947   People have studied the many planets in our so...
# 1870  The use of the facial software in class rooms ...
#
#                                          essay_text_UPD
# 49    Students around the world are forgetting more ...
# 80    President Obama has done nothing to improve ou...
# 945   People have studied the many planets in our so...
# 947   People have studied the many planets in our so...
# 1870  The use of the facial software in class rooms ...

# %%
for n, row in enumerate(temp.iterrows()):
    indx, data = row
    disc_text = data.discourse_text
    disc_text_upd = data.discourse_text_UPD

    print(f'\nN{n} === index: {indx} ===')
    print(f'\n>>> origin text:')
    print(repr(disc_text))
    print(f'\n>>> updated text:')
    print(repr(disc_text_upd))
# Out:
# N0 === index: 49 ===
#
# >>> origin text:
# "Often times throughout middle school, my teachers would give the students each other's assignments to grade themselves. And afterwards, we would see in the grade book\xa0that the grade changed because the students weren't grading the assignments the way they should have been. The student grading was meant to engage the classroom, but it turned into a showcase of how students dont really know how to grade the way teachers do. If students are unaware of how a project is supposed to be graded, they can not successfully design a project that tests whether or not they understand the material. "
#
# >>> updated text:
# "Often times throughout middle school, my teachers would give the students each other's assignments to grade themselves. And afterwards, we would see in the grade book that the grade changed because the students weren't grading the assignments the way they should have been. The student grading was meant to engage the classroom, but it turned into a showcase of how students dont really know how to grade the way teachers do. If students are unaware of how a project is supposed to be graded, they can not successfully design a project that tests whether or not they understand the material. "
#
# N1 === index: 80 ===
#
# >>> origin text:
# 'President Obama has done nothing to improve our society.\xa0 If anything, he has created the worst society this world has ever seen. \n'
#
# >>> updated text:
# 'President Obama has done nothing to improve our society.  If anything, he has created the worst society this world has ever seen. \n'
#
# N2 === index: 945 ===
#
# >>> origin text:
# 'The article says, ¨... humans have sent numerous spacecraft to land on this cloud-draped world,¨ and then says ¨... since no spacecraft survived the landing for more than a few hours.¨ If a spacecraft made by people can not survive the landing on Venus numerous times, how can we even come close to surviving the trip? Venus is too dangerous to explore and it is a waste to even send a spacecraft. The spacecrafts cost a good amount of money to make and for them to be wasted on a inhospitable planet is not worth the information we would achieve. \n'
#
# >>> updated text:
# 'The article says, "... humans have sent numerous spacecraft to land on this cloud-draped world," and then says "... since no spacecraft survived the landing for more than a few hours." If a spacecraft made by people can not survive the landing on Venus numerous times, how can we even come close to surviving the trip? Venus is too dangerous to explore and it is a waste to even send a spacecraft. The spacecrafts cost a good amount of money to make and for them to be wasted on a inhospitable planet is not worth the information we would achieve. \n'
#
# N3 === index: 947 ===
#
# >>> origin text:
# 'However, the article says that this can only give us a limited amount of information on Venus since the planet has a very dense atmosphere. The effort of creating a vehicle to hover the planet only to gain bits of knowledge is redundant and is not going the benefit anyone´s cause. \n'
#
# >>> updated text:
# "However, the article says that this can only give us a limited amount of information on Venus since the planet has a very dense atmosphere. The effort of creating a vehicle to hover the planet only to gain bits of knowledge is redundant and is not going the benefit anyone's cause. \n"
#
# N4 === index: 1870 ===
#
# >>> origin text:
# 'Many people are able to tell when a peer is angry pr sad but some people just have a blank face. The use of the software could help teachers understand their students,which in turn can help elaborate people\'s triggers and can lead to a better day."In fact, we humans perform this same impressive \x93calculation\x94 every day.\n\nFor instance, you can probably tell how a friend is feeling simply by the look on her face. \n'
#
# >>> updated text:
# 'Many people are able to tell when a peer is angry pr sad but some people just have a blank face. The use of the software could help teachers understand their students,which in turn can help elaborate people\'s triggers and can lead to a better day."In fact, we humans perform this same impressive "calculation" every day.\n\nFor instance, you can probably tell how a friend is feeling simply by the look on her face. \n'

# %% [markdown]
# # 3. Extract predictions

# %% [markdown]
# ## 3.1 DeBerta

# %%
class TestDataset(Dataset):
    def __init__(self, cfg, df):
        self.cfg = cfg
        self.text = df['text'].values

    def __len__(self):
        return len(self.text)

    def __getitem__(self, item):    
        text = self.text[item]
        inputs = prepare_input(self.cfg, text)
        
        return inputs

class CustomModel(nn.Module):
    def __init__(self, cfg, config_path=None, pretrained=False):
        super().__init__()
        self.cfg = cfg
        
        if config_path is None:
            self.config = AutoConfig.from_pretrained(cfg.model, output_hidden_states=True)
        else:
            self.config = torch.load(config_path)
        
        if pretrained:
            self.model = AutoModel.from_pretrained(cfg.model, config=self.config)
        else:
            self.model = AutoModel.from_config(self.config)
        
        self.bilstm = nn.LSTM(self.config.hidden_size, (self.config.hidden_size) // 2, num_layers=2, 
                              dropout=self.config.hidden_dropout_prob, batch_first=True,
                              bidirectional=True)
        
        # self.dropout = nn.Dropout(0.2)
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.2)
        self.dropout3 = nn.Dropout(0.3)
        self.dropout4 = nn.Dropout(0.4)
        self.dropout5 = nn.Dropout(0.5)
        
        self.output = nn.Sequential(
            nn.Linear(self.config.hidden_size, 3)  # self.cfg.target_size
        )
                
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def forward(self, inputs):
        sequence_output = self.model(**inputs)[0][:, 0, :]

        logits1 = self.output(self.dropout1(sequence_output))
        logits2 = self.output(self.dropout2(sequence_output))
        logits3 = self.output(self.dropout3(sequence_output))
        logits4 = self.output(self.dropout4(sequence_output))
        logits5 = self.output(self.dropout5(sequence_output))
        logits = (logits1 + logits2 + logits3 + logits4 + logits5) / 5

        return logits

# %%
class CFG:
    path = "../input/feedback-deberta-large-051/"
    config_path = path+'config.pth'
    model = "microsoft/deberta-large"
    num_workers = 2
    batch_size = 16
    max_len = 512
    seed = 42
    n_fold = 4
    # trn_fold = [0, 1, 2, 3]
    # fc_dropout = 0.2
    # target_size = 3
    
CFG.tokenizer = AutoTokenizer.from_pretrained(CFG.path + 'tokenizer')

# %%
df = test_origin.copy()
SEP = CFG.tokenizer.sep_token

df['discourse_text'] = df['discourse_text'].apply(resolve_encodings_and_normalize)
df['essay_text'] = df['essay_id'].transform(fetch_essay, txt_dir='test')
df['essay_text'] = df['essay_text'].apply(resolve_encodings_and_normalize)
df['text'] = df['discourse_type'] + ' ' + df['discourse_text'] + SEP + df['essay_text']

df.head()
# Out:
#    discourse_id      essay_id  \
# 0  a261b6e14276  D72CB1C11673
# 1  5a88900e7dc1  D72CB1C11673
# 2  9790d835736b  D72CB1C11673
# 3  75ce6d68b67b  D72CB1C11673
# 4  93578d946723  D72CB1C11673
#
#                                       discourse_text discourse_type  \
# 0  Making choices in life can be very difficult. ...           Lead
# 1  Seeking multiple opinions can help a person ma...       Position
# 2                     it can decrease stress levels           Claim
# 3             a great chance to learn something new           Claim
# 4               can be very helpful and beneficial.           Claim
#
#                                           essay_text  \
# 0  Making choices in life can be very difficult. ...
# 1  Making choices in life can be very difficult. ...
# 2  Making choices in life can be very difficult. ...
# 3  Making choices in life can be very difficult. ...
# 4  Making choices in life can be very difficult. ...
#
#                                                 text
# 0  Lead Making choices in life can be very diffic...
# 1  Position Seeking multiple opinions can help a ...
# 2  Claim it can decrease stress levels [SEP]Makin...
# 3  Claim a great chance to learn something new [S...
# 4  Claim can be very helpful and beneficial. [SEP...

# %%
test_dataset = TestDataset(CFG, df)
test_loader = DataLoader(test_dataset,
                         batch_size=CFG.batch_size,
                         shuffle=False,
                         num_workers=CFG.num_workers,
                         pin_memory=True, drop_last=False)

# %%
deberta_predictions = []

for fold in range(CFG.n_fold):
    model = CustomModel(CFG, config_path=CFG.config_path, pretrained=False)
    state = torch.load(CFG.path+f"{CFG.model.replace('/', '-')}_fold{fold}_best.pth",
                       map_location=torch.device('cpu'))
    
    model.load_state_dict(state['model'])
    prediction = inference_fn(test_loader, model, DEVICE)
    
    deberta_predictions.append(prediction)
    
    del model, state, prediction; gc.collect()
    torch.cuda.empty_cache()
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.02s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]

# %%
deb_ineffective = []
deb_effective = []
deb_adequate = []

for x in deberta_predictions:
    deb_ineffective.append(x[:, 0])
    deb_adequate.append(x[:, 1])
    deb_effective.append(x[:, 2])

# %%
deb_ineffective = pd.DataFrame(deb_ineffective).T

show_gradient(
    deb_ineffective,
    N_ROW)
# Out:
# <style type="text/css">
# #T_19f34_row0_col0 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_19f34_row0_col1 {
#   background-color: #d5e9d5;
#   color: #000000;
# }
# #T_19f34_row0_col2, #T_19f34_row1_col0, #T_19f34_row2_col0, #T_19f34_row3_col1, #T_19f34_row4_col2, #T_19f34_row5_col2, #T_19f34_row6_col1, #T_19f34_row7_col2, #T_19f34_row8_col2, #T_19f34_row9_col1 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_19f34_row0_col3, #T_19f34_row1_col3, #T_19f34_row2_col3, #T_19f34_row3_col0, #T_19f34_row4_col0, #T_19f34_row5_col0, #T_19f34_row6_col3, #T_19f34_row7_col1, #T_19f34_row8_col0, #T_19f34_row9_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_19f34_row0_col4 {
#   background-color: #aad3aa;
#   color: #000000;
# }
# #T_19f34_row1_col1 {
#   background-color: #c2dfc2;
#   color: #000000;
# }
# #T_19f34_row1_col2 {
#   background-color: #148a14;
#   color: #f1f1f1;
# }
# #T_19f34_row1_col4 {
#   background-color: #70b770;
#   color: #f1f1f1;
# }
# #T_19f34_row2_col1 {
#   background-color: #018001;
#   color: #f1f1f1;
# }
# #T_19f34_row2_col2 {
#   background-color: #198c19;
#   color: #f1f1f1;
# }
# #T_19f34_row2_col4 {
#   background-color: #41a041;
#   color: #f1f1f1;
# }
# #T_19f34_row3_col2 {
#   background-color: #299429;
#   color: #f1f1f1;
# }
# #T_19f34_row3_col3 {
#   background-color: #108810;
#   color: #f1f1f1;
# }
# #T_19f34_row3_col4 {
#   background-color: #49a449;
#   color: #f1f1f1;
# }
# #T_19f34_row4_col1 {
#   background-color: #6db56d;
#   color: #f1f1f1;
# }
# #T_19f34_row4_col3 {
#   background-color: #8dc58d;
#   color: #000000;
# }
# #T_19f34_row4_col4 {
#   background-color: #78bb78;
#   color: #000000;
# }
# #T_19f34_row5_col1 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_19f34_row5_col3 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# #T_19f34_row5_col4 {
#   background-color: #acd4ac;
#   color: #000000;
# }
# #T_19f34_row6_col0 {
#   background-color: #cae3ca;
#   color: #000000;
# }
# #T_19f34_row6_col2 {
#   background-color: #068306;
#   color: #f1f1f1;
# }
# #T_19f34_row6_col4 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_19f34_row7_col0 {
#   background-color: #e0eee0;
#   color: #000000;
# }
# #T_19f34_row7_col3 {
#   background-color: #a0cea0;
#   color: #000000;
# }
# #T_19f34_row7_col4 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_19f34_row8_col1 {
#   background-color: #b4d8b4;
#   color: #000000;
# }
# #T_19f34_row8_col3 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_19f34_row8_col4 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_19f34_row9_col2 {
#   background-color: #329832;
#   color: #f1f1f1;
# }
# #T_19f34_row9_col3 {
#   background-color: #51a851;
#   color: #f1f1f1;
# }
# #T_19f34_row9_col4 {
#   background-color: #5bad5b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_19f34_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >all_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19f34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19f34_row0_col0" class="data row0 col0" >0.0026</td>
#       <td id="T_19f34_row0_col1" class="data row0 col1" >0.0037</td>
#       <td id="T_19f34_row0_col2" class="data row0 col2" >0.0154</td>
#       <td id="T_19f34_row0_col3" class="data row0 col3" >0.0025</td>
#       <td id="T_19f34_row0_col4" class="data row0 col4" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_19f34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19f34_row1_col0" class="data row1 col0" >0.0443</td>
#       <td id="T_19f34_row1_col1" class="data row1 col1" >0.0230</td>
#       <td id="T_19f34_row1_col2" class="data row1 col2" >0.0420</td>
#       <td id="T_19f34_row1_col3" class="data row1 col3" >0.0186</td>
#       <td id="T_19f34_row1_col4" class="data row1 col4" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_19f34_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19f34_row2_col0" class="data row2 col0" >0.0280</td>
#       <td id="T_19f34_row2_col1" class="data row2 col1" >0.0279</td>
#       <td id="T_19f34_row2_col2" class="data row2 col2" >0.0270</td>
#       <td id="T_19f34_row2_col3" class="data row2 col3" >0.0190</td>
#       <td id="T_19f34_row2_col4" class="data row2 col4" >0.0255</td>
#     </tr>
#     <tr>
#       <th id="T_19f34_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_19f34_row3_col0" class="data row3 col0" >0.0525</td>
#       <td id="T_19f34_row3_col1" class="data row3 col1" >0.0790</td>
#       <td id="T_19f34_row3_col2" class="data row3 col2" >0.0743</td>
#       <td id="T_19f34_row3_col3" class="data row3 col3" >0.0773</td>
#       <td id="T_19f34_row3_col4" class="data row3 col4" >0.0708</td>
#     </tr>
#     <tr>
#       <th id="T_19f34_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_19f34_row4_col0" class="data row4 col0" >0.0318</td>
#       <td id="T_19f34_row4_col1" class="data row4 col1" >0.0547</td>
#       <td id="T_19f34_row4_col2" class="data row4 col2" >0.0745</td>
#       <td id="T_19f34_row4_col3" class="data row4 col3" >0.0489</td>
#       <td id="T_19f34_row4_col4" class="data row4 col4" >0.0525</td>
#     </tr>
#     <tr>
#       <th id="T_19f34_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_19f34_row5_col0" class="data row5 col0" >0.0076</td>
#       <td id="T_19f34_row5_col1" class="data row5 col1" >0.0084</td>
#       <td id="T_19f34_row5_col2" class="data row5 col2" >0.0217</td>
#       <td id="T_19f34_row5_col3" class="data row5 col3" >0.0078</td>
#       <td id="T_19f34_row5_col4" class="data row5 col4" >0.0114</td>
#     </tr>
#     <tr>
#       <th id="T_19f34_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_19f34_row6_col0" class="data row6 col0" >0.0052</td>
#       <td id="T_19f34_row6_col1" class="data row6 col1" >0.0093</td>
#       <td id="T_19f34_row6_col2" class="data row6 col2" >0.0092</td>
#       <td id="T_19f34_row6_col3" class="data row6 col3" >0.0045</td>
#       <td id="T_19f34_row6_col4" class="data row6 col4" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_19f34_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_19f34_row7_col0" class="data row7 col0" >0.0142</td>
#       <td id="T_19f34_row7_col1" class="data row7 col1" >0.0130</td>
#       <td id="T_19f34_row7_col2" class="data row7 col2" >0.0380</td>
#       <td id="T_19f34_row7_col3" class="data row7 col3" >0.0209</td>
#       <td id="T_19f34_row7_col4" class="data row7 col4" >0.0215</td>
#     </tr>
#     <tr>
#       <th id="T_19f34_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_19f34_row8_col0" class="data row8 col0" >0.0110</td>
#       <td id="T_19f34_row8_col1" class="data row8 col1" >0.0194</td>
#       <td id="T_19f34_row8_col2" class="data row8 col2" >0.0474</td>
#       <td id="T_19f34_row8_col3" class="data row8 col3" >0.0149</td>
#       <td id="T_19f34_row8_col4" class="data row8 col4" >0.0232</td>
#     </tr>
#     <tr>
#       <th id="T_19f34_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_19f34_row9_col0" class="data row9 col0" >0.0089</td>
#       <td id="T_19f34_row9_col1" class="data row9 col1" >0.0106</td>
#       <td id="T_19f34_row9_col2" class="data row9 col2" >0.0102</td>
#       <td id="T_19f34_row9_col3" class="data row9 col3" >0.0100</td>
#       <td id="T_19f34_row9_col4" class="data row9 col4" >0.0099</td>
#     </tr>
#   </tbody>
# </table>

# %%
deb_adequate = pd.DataFrame(deb_adequate).T

show_gradient(
    deb_adequate,
    N_ROW)
# Out:
# <style type="text/css">
# #T_7b765_row0_col0, #T_7b765_row1_col2, #T_7b765_row2_col2, #T_7b765_row3_col2, #T_7b765_row4_col3, #T_7b765_row5_col0, #T_7b765_row6_col3, #T_7b765_row7_col0, #T_7b765_row8_col0, #T_7b765_row9_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_7b765_row0_col1 {
#   background-color: #81bf81;
#   color: #000000;
# }
# #T_7b765_row0_col2, #T_7b765_row1_col3, #T_7b765_row2_col1, #T_7b765_row3_col1, #T_7b765_row4_col1, #T_7b765_row5_col2, #T_7b765_row6_col1, #T_7b765_row7_col3, #T_7b765_row8_col2, #T_7b765_row9_col1 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_7b765_row0_col3 {
#   background-color: #e4f0e4;
#   color: #000000;
# }
# #T_7b765_row0_col4 {
#   background-color: #94c994;
#   color: #000000;
# }
# #T_7b765_row1_col0 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_7b765_row1_col1 {
#   background-color: #1f8f1f;
#   color: #f1f1f1;
# }
# #T_7b765_row1_col4 {
#   background-color: #60af60;
#   color: #f1f1f1;
# }
# #T_7b765_row2_col0 {
#   background-color: #8dc58d;
#   color: #000000;
# }
# #T_7b765_row2_col3 {
#   background-color: #038103;
#   color: #f1f1f1;
# }
# #T_7b765_row2_col4 {
#   background-color: #5fae5f;
#   color: #f1f1f1;
# }
# #T_7b765_row3_col0 {
#   background-color: #45a245;
#   color: #f1f1f1;
# }
# #T_7b765_row3_col3 {
#   background-color: #2a952a;
#   color: #f1f1f1;
# }
# #T_7b765_row3_col4 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_7b765_row4_col0 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_7b765_row4_col2 {
#   background-color: #7abc7a;
#   color: #000000;
# }
# #T_7b765_row4_col4 {
#   background-color: #86c286;
#   color: #000000;
# }
# #T_7b765_row5_col1, #T_7b765_row9_col3 {
#   background-color: #1e8f1e;
#   color: #f1f1f1;
# }
# #T_7b765_row5_col3 {
#   background-color: #84c084;
#   color: #000000;
# }
# #T_7b765_row5_col4, #T_7b765_row7_col4 {
#   background-color: #63b163;
#   color: #f1f1f1;
# }
# #T_7b765_row6_col0 {
#   background-color: #bddcbd;
#   color: #000000;
# }
# #T_7b765_row6_col2 {
#   background-color: #92c892;
#   color: #000000;
# }
# #T_7b765_row6_col4 {
#   background-color: #8fc68f;
#   color: #000000;
# }
# #T_7b765_row7_col1 {
#   background-color: #188c18;
#   color: #f1f1f1;
# }
# #T_7b765_row7_col2 {
#   background-color: #8ac48a;
#   color: #000000;
# }
# #T_7b765_row8_col1 {
#   background-color: #4ba54b;
#   color: #f1f1f1;
# }
# #T_7b765_row8_col3 {
#   background-color: #99cb99;
#   color: #000000;
# }
# #T_7b765_row8_col4 {
#   background-color: #74b974;
#   color: #f1f1f1;
# }
# #T_7b765_row9_col2 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_7b765_row9_col4 {
#   background-color: #69b369;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7b765_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >all_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b765_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b765_row0_col0" class="data row0 col0" >0.2618</td>
#       <td id="T_7b765_row0_col1" class="data row0 col1" >0.3429</td>
#       <td id="T_7b765_row0_col2" class="data row0 col2" >0.4421</td>
#       <td id="T_7b765_row0_col3" class="data row0 col3" >0.2671</td>
#       <td id="T_7b765_row0_col4" class="data row0 col4" >0.3285</td>
#     </tr>
#     <tr>
#       <th id="T_7b765_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b765_row1_col0" class="data row1 col0" >0.8806</td>
#       <td id="T_7b765_row1_col1" class="data row1 col1" >0.9091</td>
#       <td id="T_7b765_row1_col2" class="data row1 col2" >0.8394</td>
#       <td id="T_7b765_row1_col3" class="data row1 col3" >0.9201</td>
#       <td id="T_7b765_row1_col4" class="data row1 col4" >0.8873</td>
#     </tr>
#     <tr>
#       <th id="T_7b765_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b765_row2_col0" class="data row2 col0" >0.7148</td>
#       <td id="T_7b765_row2_col1" class="data row2 col1" >0.8394</td>
#       <td id="T_7b765_row2_col2" class="data row2 col2" >0.6311</td>
#       <td id="T_7b765_row2_col3" class="data row2 col3" >0.8366</td>
#       <td id="T_7b765_row2_col4" class="data row2 col4" >0.7555</td>
#     </tr>
#     <tr>
#       <th id="T_7b765_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b765_row3_col0" class="data row3 col0" >0.7037</td>
#       <td id="T_7b765_row3_col1" class="data row3 col1" >0.7460</td>
#       <td id="T_7b765_row3_col2" class="data row3 col2" >0.6031</td>
#       <td id="T_7b765_row3_col3" class="data row3 col3" >0.7203</td>
#       <td id="T_7b765_row3_col4" class="data row3 col4" >0.6933</td>
#     </tr>
#     <tr>
#       <th id="T_7b765_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7b765_row4_col0" class="data row4 col0" >0.5960</td>
#       <td id="T_7b765_row4_col1" class="data row4 col1" >0.7368</td>
#       <td id="T_7b765_row4_col2" class="data row4 col2" >0.6416</td>
#       <td id="T_7b765_row4_col3" class="data row4 col3" >0.5543</td>
#       <td id="T_7b765_row4_col4" class="data row4 col4" >0.6322</td>
#     </tr>
#     <tr>
#       <th id="T_7b765_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7b765_row5_col0" class="data row5 col0" >0.3068</td>
#       <td id="T_7b765_row5_col1" class="data row5 col1" >0.4171</td>
#       <td id="T_7b765_row5_col2" class="data row5 col2" >0.4339</td>
#       <td id="T_7b765_row5_col3" class="data row5 col3" >0.3624</td>
#       <td id="T_7b765_row5_col4" class="data row5 col4" >0.3801</td>
#     </tr>
#     <tr>
#       <th id="T_7b765_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7b765_row6_col0" class="data row6 col0" >0.2087</td>
#       <td id="T_7b765_row6_col1" class="data row6 col1" >0.3003</td>
#       <td id="T_7b765_row6_col2" class="data row6 col2" >0.2288</td>
#       <td id="T_7b765_row6_col3" class="data row6 col3" >0.1859</td>
#       <td id="T_7b765_row6_col4" class="data row6 col4" >0.2309</td>
#     </tr>
#     <tr>
#       <th id="T_7b765_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7b765_row7_col0" class="data row7 col0" >0.5164</td>
#       <td id="T_7b765_row7_col1" class="data row7 col1" >0.7484</td>
#       <td id="T_7b765_row7_col2" class="data row7 col2" >0.6227</td>
#       <td id="T_7b765_row7_col3" class="data row7 col3" >0.7748</td>
#       <td id="T_7b765_row7_col4" class="data row7 col4" >0.6656</td>
#     </tr>
#     <tr>
#       <th id="T_7b765_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7b765_row8_col0" class="data row8 col0" >0.2912</td>
#       <td id="T_7b765_row8_col1" class="data row8 col1" >0.4925</td>
#       <td id="T_7b765_row8_col2" class="data row8 col2" >0.5889</td>
#       <td id="T_7b765_row8_col3" class="data row8 col3" >0.3951</td>
#       <td id="T_7b765_row8_col4" class="data row8 col4" >0.4419</td>
#     </tr>
#     <tr>
#       <th id="T_7b765_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7b765_row9_col0" class="data row9 col0" >0.4598</td>
#       <td id="T_7b765_row9_col1" class="data row9 col1" >0.6757</td>
#       <td id="T_7b765_row9_col2" class="data row9 col2" >0.5322</td>
#       <td id="T_7b765_row9_col3" class="data row9 col3" >0.6476</td>
#       <td id="T_7b765_row9_col4" class="data row9 col4" >0.5788</td>
#     </tr>
#   </tbody>
# </table>

# %%
deb_effective = pd.DataFrame(deb_effective).T

show_gradient(
    deb_effective,
    N_ROW)
# Out:
# <style type="text/css">
# #T_da0f2_row0_col0, #T_da0f2_row1_col2, #T_da0f2_row2_col2, #T_da0f2_row3_col2, #T_da0f2_row4_col3, #T_da0f2_row5_col0, #T_da0f2_row6_col3, #T_da0f2_row7_col0, #T_da0f2_row8_col0, #T_da0f2_row9_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_da0f2_row0_col1 {
#   background-color: #63b163;
#   color: #f1f1f1;
# }
# #T_da0f2_row0_col2, #T_da0f2_row1_col3, #T_da0f2_row2_col1, #T_da0f2_row3_col1, #T_da0f2_row4_col1, #T_da0f2_row5_col2, #T_da0f2_row6_col1, #T_da0f2_row7_col3, #T_da0f2_row8_col2, #T_da0f2_row9_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_da0f2_row0_col3 {
#   background-color: #068306;
#   color: #f1f1f1;
# }
# #T_da0f2_row0_col4 {
#   background-color: #55a955;
#   color: #f1f1f1;
# }
# #T_da0f2_row1_col0 {
#   background-color: #b2d7b2;
#   color: #000000;
# }
# #T_da0f2_row1_col1 {
#   background-color: #d0e6d0;
#   color: #000000;
# }
# #T_da0f2_row1_col4 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_da0f2_row2_col0 {
#   background-color: #5fae5f;
#   color: #f1f1f1;
# }
# #T_da0f2_row2_col3 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_da0f2_row2_col4, #T_da0f2_row3_col4 {
#   background-color: #8ac48a;
#   color: #000000;
# }
# #T_da0f2_row3_col0 {
#   background-color: #7dbd7d;
#   color: #000000;
# }
# #T_da0f2_row3_col3 {
#   background-color: #bfdebf;
#   color: #000000;
# }
# #T_da0f2_row4_col0 {
#   background-color: #1e8f1e;
#   color: #f1f1f1;
# }
# #T_da0f2_row4_col2 {
#   background-color: #8dc58d;
#   color: #000000;
# }
# #T_da0f2_row4_col4 {
#   background-color: #65b265;
#   color: #f1f1f1;
# }
# #T_da0f2_row5_col1 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_da0f2_row5_col3 {
#   background-color: #5dae5d;
#   color: #f1f1f1;
# }
# #T_da0f2_row5_col4 {
#   background-color: #80bf80;
#   color: #000000;
# }
# #T_da0f2_row6_col0 {
#   background-color: #2e972e;
#   color: #f1f1f1;
# }
# #T_da0f2_row6_col2, #T_da0f2_row6_col4 {
#   background-color: #5eae5e;
#   color: #f1f1f1;
# }
# #T_da0f2_row7_col1, #T_da0f2_row9_col3 {
#   background-color: #cce4cc;
#   color: #000000;
# }
# #T_da0f2_row7_col2 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_da0f2_row7_col4 {
#   background-color: #8bc48b;
#   color: #000000;
# }
# #T_da0f2_row8_col1 {
#   background-color: #93c893;
#   color: #000000;
# }
# #T_da0f2_row8_col3 {
#   background-color: #4ba54b;
#   color: #f1f1f1;
# }
# #T_da0f2_row8_col4 {
#   background-color: #72b872;
#   color: #f1f1f1;
# }
# #T_da0f2_row9_col2 {
#   background-color: #4fa74f;
#   color: #f1f1f1;
# }
# #T_da0f2_row9_col4 {
#   background-color: #82c082;
#   color: #000000;
# }
# </style>
# <table id="T_da0f2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >all_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da0f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da0f2_row0_col0" class="data row0 col0" >0.7356</td>
#       <td id="T_da0f2_row0_col1" class="data row0 col1" >0.6535</td>
#       <td id="T_da0f2_row0_col2" class="data row0 col2" >0.5426</td>
#       <td id="T_da0f2_row0_col3" class="data row0 col3" >0.7304</td>
#       <td id="T_da0f2_row0_col4" class="data row0 col4" >0.6655</td>
#     </tr>
#     <tr>
#       <th id="T_da0f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da0f2_row1_col0" class="data row1 col0" >0.0751</td>
#       <td id="T_da0f2_row1_col1" class="data row1 col1" >0.0679</td>
#       <td id="T_da0f2_row1_col2" class="data row1 col2" >0.1186</td>
#       <td id="T_da0f2_row1_col3" class="data row1 col3" >0.0613</td>
#       <td id="T_da0f2_row1_col4" class="data row1 col4" >0.0807</td>
#     </tr>
#     <tr>
#       <th id="T_da0f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_da0f2_row2_col0" class="data row2 col0" >0.2572</td>
#       <td id="T_da0f2_row2_col1" class="data row2 col1" >0.1327</td>
#       <td id="T_da0f2_row2_col2" class="data row2 col2" >0.3419</td>
#       <td id="T_da0f2_row2_col3" class="data row2 col3" >0.1444</td>
#       <td id="T_da0f2_row2_col4" class="data row2 col4" >0.2190</td>
#     </tr>
#     <tr>
#       <th id="T_da0f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_da0f2_row3_col0" class="data row3 col0" >0.2438</td>
#       <td id="T_da0f2_row3_col1" class="data row3 col1" >0.1749</td>
#       <td id="T_da0f2_row3_col2" class="data row3 col2" >0.3226</td>
#       <td id="T_da0f2_row3_col3" class="data row3 col3" >0.2025</td>
#       <td id="T_da0f2_row3_col4" class="data row3 col4" >0.2359</td>
#     </tr>
#     <tr>
#       <th id="T_da0f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_da0f2_row4_col0" class="data row4 col0" >0.3722</td>
#       <td id="T_da0f2_row4_col1" class="data row4 col1" >0.2085</td>
#       <td id="T_da0f2_row4_col2" class="data row4 col2" >0.2839</td>
#       <td id="T_da0f2_row4_col3" class="data row4 col3" >0.3968</td>
#       <td id="T_da0f2_row4_col4" class="data row4 col4" >0.3154</td>
#     </tr>
#     <tr>
#       <th id="T_da0f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_da0f2_row5_col0" class="data row5 col0" >0.6856</td>
#       <td id="T_da0f2_row5_col1" class="data row5 col1" >0.5745</td>
#       <td id="T_da0f2_row5_col2" class="data row5 col2" >0.5444</td>
#       <td id="T_da0f2_row5_col3" class="data row5 col3" >0.6297</td>
#       <td id="T_da0f2_row5_col4" class="data row5 col4" >0.6086</td>
#     </tr>
#     <tr>
#       <th id="T_da0f2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_da0f2_row6_col0" class="data row6 col0" >0.7861</td>
#       <td id="T_da0f2_row6_col1" class="data row6 col1" >0.6904</td>
#       <td id="T_da0f2_row6_col2" class="data row6 col2" >0.7620</td>
#       <td id="T_da0f2_row6_col3" class="data row6 col3" >0.8096</td>
#       <td id="T_da0f2_row6_col4" class="data row6 col4" >0.7620</td>
#     </tr>
#     <tr>
#       <th id="T_da0f2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_da0f2_row7_col0" class="data row7 col0" >0.4695</td>
#       <td id="T_da0f2_row7_col1" class="data row7 col1" >0.2386</td>
#       <td id="T_da0f2_row7_col2" class="data row7 col2" >0.3393</td>
#       <td id="T_da0f2_row7_col3" class="data row7 col3" >0.2042</td>
#       <td id="T_da0f2_row7_col4" class="data row7 col4" >0.3129</td>
#     </tr>
#     <tr>
#       <th id="T_da0f2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_da0f2_row8_col0" class="data row8 col0" >0.6978</td>
#       <td id="T_da0f2_row8_col1" class="data row8 col1" >0.4881</td>
#       <td id="T_da0f2_row8_col2" class="data row8 col2" >0.3636</td>
#       <td id="T_da0f2_row8_col3" class="data row8 col3" >0.5900</td>
#       <td id="T_da0f2_row8_col4" class="data row8 col4" >0.5349</td>
#     </tr>
#     <tr>
#       <th id="T_da0f2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_da0f2_row9_col0" class="data row9 col0" >0.5313</td>
#       <td id="T_da0f2_row9_col1" class="data row9 col1" >0.3137</td>
#       <td id="T_da0f2_row9_col2" class="data row9 col2" >0.4576</td>
#       <td id="T_da0f2_row9_col3" class="data row9 col3" >0.3424</td>
#       <td id="T_da0f2_row9_col4" class="data row9 col4" >0.4113</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3.2 RoBerta

# %%
class TestDataset(Dataset):
    def __init__(self, cfg, df):
        self.cfg = cfg
        self.discourse = df['discourse'].values
        self.essay = df['essay'].values
        
    def __len__(self):
        return len(self.discourse)
    
    def __getitem__(self, item):
        discourse = self.discourse[item]
        essay = self.essay[item]
        
        inputs = prepare_input(self.cfg, discourse, essay)
        
        return inputs
        
class FeedBackModel(nn.Module):
    def __init__(self, model_path):
        super(FeedBackModel, self).__init__()
        self.model = AutoModel.from_pretrained(model_path)
        self.linear = nn.Linear(768, 3)

    def forward(self, inputs):
        last_hidden_states = self.model(**inputs)[0][:, 0, :]
        outputs = self.linear(last_hidden_states)
        
        return outputs

# %%
model_list = pickle.load(
    open("../input/feedback-roberta-ep1/roberta_modellist_ep2.pkl", "rb")
)

class CFG:
    path = "../input/roberta-base/"
    n_fold = 5
    batch = 16
    max_len = 512
    num_workers = 2
    
CFG.tokenizer = AutoTokenizer.from_pretrained(CFG.path)

# %%
df = test_origin.copy()

txt_sep = " "
df['discourse'] = df['discourse_type'].str.lower().str.strip() + txt_sep \
                + df['discourse_text'].str.lower().str.strip()

df['essay'] = df['essay_id'].transform(fetch_essay, txt_dir='test').str.lower().str.strip()
df.head()
# Out:
#    discourse_id      essay_id  \
# 0  a261b6e14276  D72CB1C11673
# 1  5a88900e7dc1  D72CB1C11673
# 2  9790d835736b  D72CB1C11673
# 3  75ce6d68b67b  D72CB1C11673
# 4  93578d946723  D72CB1C11673
#
#                                       discourse_text discourse_type  \
# 0  Making choices in life can be very difficult. ...           Lead
# 1  Seeking multiple opinions can help a person ma...       Position
# 2                     it can decrease stress levels           Claim
# 3             a great chance to learn something new           Claim
# 4               can be very helpful and beneficial.           Claim
#
#                                            discourse  \
# 0  lead making choices in life can be very diffic...
# 1  position seeking multiple opinions can help a ...
# 2                claim it can decrease stress levels
# 3        claim a great chance to learn something new
# 4          claim can be very helpful and beneficial.
#
#                                                essay
# 0  making choices in life can be very difficult. ...
# 1  making choices in life can be very difficult. ...
# 2  making choices in life can be very difficult. ...
# 3  making choices in life can be very difficult. ...
# 4  making choices in life can be very difficult. ...

# %%
test_dataset = TestDataset(CFG, df)
test_loader = DataLoader(test_dataset, batch_size=CFG.batch,
                         shuffle=False, num_workers=CFG.num_workers,
                         pin_memory=True, drop_last=False)

# %%
roberta_predicts = []
for i in range(CFG.n_fold):
    model = model_list[i]
    
    prediction = inference_fn(test_loader, model, DEVICE)
    roberta_predicts.append(prediction)
    
    del model, prediction
    torch.cuda.empty_cache()    
    gc.collect()
    
del model_list
gc.collect()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.28it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# 0

# %%
rob_ineffective = []
rob_effective = []
rob_adequate = []

for x in roberta_predicts:
    rob_ineffective.append(x[:, 0])
    rob_adequate.append(x[:, 1])
    rob_effective.append(x[:, 2])

# %%
rob_ineffective = pd.DataFrame(rob_ineffective).T

show_gradient(
    rob_ineffective,
    N_ROW)
# Out:
# <style type="text/css">
# #T_77c10_row0_col0, #T_77c10_row1_col3, #T_77c10_row2_col3, #T_77c10_row3_col3, #T_77c10_row4_col3, #T_77c10_row5_col3, #T_77c10_row6_col3, #T_77c10_row7_col3, #T_77c10_row8_col3, #T_77c10_row9_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_77c10_row0_col1 {
#   background-color: #44a144;
#   color: #f1f1f1;
# }
# #T_77c10_row0_col2 {
#   background-color: #bddcbd;
#   color: #000000;
# }
# #T_77c10_row0_col3 {
#   background-color: #c9e3c9;
#   color: #000000;
# }
# #T_77c10_row0_col4, #T_77c10_row1_col4, #T_77c10_row2_col0, #T_77c10_row3_col4, #T_77c10_row4_col2, #T_77c10_row5_col4, #T_77c10_row6_col4, #T_77c10_row7_col4, #T_77c10_row8_col0, #T_77c10_row9_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_77c10_row0_col5 {
#   background-color: #8ac48a;
#   color: #000000;
# }
# #T_77c10_row1_col0, #T_77c10_row1_col2 {
#   background-color: #c0dec0;
#   color: #000000;
# }
# #T_77c10_row1_col1 {
#   background-color: #78bb78;
#   color: #000000;
# }
# #T_77c10_row1_col5 {
#   background-color: #94c994;
#   color: #000000;
# }
# #T_77c10_row2_col1 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_77c10_row2_col2 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_77c10_row2_col4 {
#   background-color: #5eae5e;
#   color: #f1f1f1;
# }
# #T_77c10_row2_col5 {
#   background-color: #7dbd7d;
#   color: #000000;
# }
# #T_77c10_row3_col0, #T_77c10_row8_col5, #T_77c10_row9_col0 {
#   background-color: #68b368;
#   color: #f1f1f1;
# }
# #T_77c10_row3_col1 {
#   background-color: #cbe4cb;
#   color: #000000;
# }
# #T_77c10_row3_col2 {
#   background-color: #77ba77;
#   color: #f1f1f1;
# }
# #T_77c10_row3_col5 {
#   background-color: #84c184;
#   color: #000000;
# }
# #T_77c10_row4_col0, #T_77c10_row4_col4 {
#   background-color: #2e972e;
#   color: #f1f1f1;
# }
# #T_77c10_row4_col1 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_77c10_row4_col5 {
#   background-color: #61af61;
#   color: #f1f1f1;
# }
# #T_77c10_row5_col0 {
#   background-color: #8ec58e;
#   color: #000000;
# }
# #T_77c10_row5_col1 {
#   background-color: #90c790;
#   color: #000000;
# }
# #T_77c10_row5_col2 {
#   background-color: #a6d1a6;
#   color: #000000;
# }
# #T_77c10_row5_col5 {
#   background-color: #89c389;
#   color: #000000;
# }
# #T_77c10_row6_col0 {
#   background-color: #b1d7b1;
#   color: #000000;
# }
# #T_77c10_row6_col1 {
#   background-color: #a0cea0;
#   color: #000000;
# }
# #T_77c10_row6_col2 {
#   background-color: #c5e0c5;
#   color: #000000;
# }
# #T_77c10_row6_col5 {
#   background-color: #9acb9a;
#   color: #000000;
# }
# #T_77c10_row7_col0 {
#   background-color: #71b771;
#   color: #f1f1f1;
# }
# #T_77c10_row7_col1 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_77c10_row7_col2 {
#   background-color: #97ca97;
#   color: #000000;
# }
# #T_77c10_row7_col5 {
#   background-color: #88c388;
#   color: #000000;
# }
# #T_77c10_row8_col1 {
#   background-color: #95c995;
#   color: #000000;
# }
# #T_77c10_row8_col2 {
#   background-color: #3e9e3e;
#   color: #f1f1f1;
# }
# #T_77c10_row8_col4 {
#   background-color: #4ba54b;
#   color: #f1f1f1;
# }
# #T_77c10_row9_col2 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_77c10_row9_col3 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_77c10_row9_col5 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# </style>
# <table id="T_77c10_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >all_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77c10_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77c10_row0_col0" class="data row0 col0" >0.0055</td>
#       <td id="T_77c10_row0_col1" class="data row0 col1" >0.0284</td>
#       <td id="T_77c10_row0_col2" class="data row0 col2" >0.0119</td>
#       <td id="T_77c10_row0_col3" class="data row0 col3" >0.0101</td>
#       <td id="T_77c10_row0_col4" class="data row0 col4" >0.0377</td>
#       <td id="T_77c10_row0_col5" class="data row0 col5" >0.0187</td>
#     </tr>
#     <tr>
#       <th id="T_77c10_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77c10_row1_col0" class="data row1 col0" >0.0191</td>
#       <td id="T_77c10_row1_col1" class="data row1 col1" >0.0364</td>
#       <td id="T_77c10_row1_col2" class="data row1 col2" >0.0190</td>
#       <td id="T_77c10_row1_col3" class="data row1 col3" >0.0087</td>
#       <td id="T_77c10_row1_col4" class="data row1 col4" >0.0658</td>
#       <td id="T_77c10_row1_col5" class="data row1 col5" >0.0298</td>
#     </tr>
#     <tr>
#       <th id="T_77c10_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_77c10_row2_col0" class="data row2 col0" >0.0269</td>
#       <td id="T_77c10_row2_col1" class="data row2 col1" >0.0066</td>
#       <td id="T_77c10_row2_col2" class="data row2 col2" >0.0186</td>
#       <td id="T_77c10_row2_col3" class="data row2 col3" >0.0045</td>
#       <td id="T_77c10_row2_col4" class="data row2 col4" >0.0178</td>
#       <td id="T_77c10_row2_col5" class="data row2 col5" >0.0149</td>
#     </tr>
#     <tr>
#       <th id="T_77c10_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_77c10_row3_col0" class="data row3 col0" >0.0164</td>
#       <td id="T_77c10_row3_col1" class="data row3 col1" >0.0064</td>
#       <td id="T_77c10_row3_col2" class="data row3 col2" >0.0149</td>
#       <td id="T_77c10_row3_col3" class="data row3 col3" >0.0032</td>
#       <td id="T_77c10_row3_col4" class="data row3 col4" >0.0269</td>
#       <td id="T_77c10_row3_col5" class="data row3 col5" >0.0135</td>
#     </tr>
#     <tr>
#       <th id="T_77c10_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_77c10_row4_col0" class="data row4 col0" >0.0209</td>
#       <td id="T_77c10_row4_col1" class="data row4 col1" >0.0101</td>
#       <td id="T_77c10_row4_col2" class="data row4 col2" >0.0255</td>
#       <td id="T_77c10_row4_col3" class="data row4 col3" >0.0023</td>
#       <td id="T_77c10_row4_col4" class="data row4 col4" >0.0209</td>
#       <td id="T_77c10_row4_col5" class="data row4 col5" >0.0159</td>
#     </tr>
#     <tr>
#       <th id="T_77c10_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_77c10_row5_col0" class="data row5 col0" >0.0070</td>
#       <td id="T_77c10_row5_col1" class="data row5 col1" >0.0068</td>
#       <td id="T_77c10_row5_col2" class="data row5 col2" >0.0057</td>
#       <td id="T_77c10_row5_col3" class="data row5 col3" >0.0021</td>
#       <td id="T_77c10_row5_col4" class="data row5 col4" >0.0145</td>
#       <td id="T_77c10_row5_col5" class="data row5 col5" >0.0072</td>
#     </tr>
#     <tr>
#       <th id="T_77c10_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_77c10_row6_col0" class="data row6 col0" >0.0090</td>
#       <td id="T_77c10_row6_col1" class="data row6 col1" >0.0107</td>
#       <td id="T_77c10_row6_col2" class="data row6 col2" >0.0068</td>
#       <td id="T_77c10_row6_col3" class="data row6 col3" >0.0029</td>
#       <td id="T_77c10_row6_col4" class="data row6 col4" >0.0274</td>
#       <td id="T_77c10_row6_col5" class="data row6 col5" >0.0114</td>
#     </tr>
#     <tr>
#       <th id="T_77c10_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_77c10_row7_col0" class="data row7 col0" >0.0105</td>
#       <td id="T_77c10_row7_col1" class="data row7 col1" >0.0054</td>
#       <td id="T_77c10_row7_col2" class="data row7 col2" >0.0077</td>
#       <td id="T_77c10_row7_col3" class="data row7 col3" >0.0014</td>
#       <td id="T_77c10_row7_col4" class="data row7 col4" >0.0190</td>
#       <td id="T_77c10_row7_col5" class="data row7 col5" >0.0088</td>
#     </tr>
#     <tr>
#       <th id="T_77c10_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_77c10_row8_col0" class="data row8 col0" >0.0119</td>
#       <td id="T_77c10_row8_col1" class="data row8 col1" >0.0058</td>
#       <td id="T_77c10_row8_col2" class="data row8 col2" >0.0093</td>
#       <td id="T_77c10_row8_col3" class="data row8 col3" >0.0023</td>
#       <td id="T_77c1

# %%
rob_adequate = pd.DataFrame(rob_adequate).T

show_gradient(
    rob_adequate,
    N_ROW)
# Out:
# <style type="text/css">
# #T_8b519_row0_col0, #T_8b519_row1_col3, #T_8b519_row2_col3, #T_8b519_row3_col3, #T_8b519_row4_col3, #T_8b519_row5_col3, #T_8b519_row6_col3, #T_8b519_row7_col3, #T_8b519_row8_col3, #T_8b519_row9_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_8b519_row0_col1, #T_8b519_row1_col1, #T_8b519_row2_col0, #T_8b519_row3_col4, #T_8b519_row4_col0, #T_8b519_row5_col1, #T_8b519_row6_col4, #T_8b519_row7_col4, #T_8b519_row8_col0, #T_8b519_row9_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_8b519_row0_col2, #T_8b519_row7_col2 {
#   background-color: #72b872;
#   color: #f1f1f1;
# }
# #T_8b519_row0_col3 {
#   background-color: #76ba76;
#   color: #f1f1f1;
# }
# #T_8b519_row0_col4 {
#   background-color: #028102;
#   color: #f1f1f1;
# }
# #T_8b519_row0_col5, #T_8b519_row5_col5, #T_8b519_row6_col0 {
#   background-color: #5eae5e;
#   color: #f1f1f1;
# }
# #T_8b519_row1_col0 {
#   background-color: #4ba54a;
#   color: #f1f1f1;
# }
# #T_8b519_row1_col2 {
#   background-color: #2d962d;
#   color: #f1f1f1;
# }
# #T_8b519_row1_col4, #T_8b519_row6_col1 {
#   background-color: #0f870f;
#   color: #f1f1f1;
# }
# #T_8b519_row1_col5 {
#   background-color: #4aa44a;
#   color: #f1f1f1;
# }
# #T_8b519_row2_col1 {
#   background-color: #74b974;
#   color: #f1f1f1;
# }
# #T_8b519_row2_col2 {
#   background-color: #59ac59;
#   color: #f1f1f1;
# }
# #T_8b519_row2_col4, #T_8b519_row3_col1 {
#   background-color: #6cb56c;
#   color: #f1f1f1;
# }
# #T_8b519_row2_col5 {
#   background-color: #6db66d;
#   color: #f1f1f1;
# }
# #T_8b519_row3_col0 {
#   background-color: #138913;
#   color: #f1f1f1;
# }
# #T_8b519_row3_col2 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_8b519_row3_col5 {
#   background-color: #5fae5f;
#   color: #f1f1f1;
# }
# #T_8b519_row4_col1 {
#   background-color: #43a143;
#   color: #f1f1f1;
# }
# #T_8b519_row4_col2 {
#   background-color: #229122;
#   color: #f1f1f1;
# }
# #T_8b519_row4_col4, #T_8b519_row8_col2 {
#   background-color: #3b9d3b;
#   color: #f1f1f1;
# }
# #T_8b519_row4_col5 {
#   background-color: #4fa74f;
#   color: #f1f1f1;
# }
# #T_8b519_row5_col0 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_8b519_row5_col2 {
#   background-color: #7bbc7b;
#   color: #000000;
# }
# #T_8b519_row5_col4 {
#   background-color: #1b8d1b;
#   color: #f1f1f1;
# }
# #T_8b519_row6_col2 {
#   background-color: #b6d9b6;
#   color: #000000;
# }
# #T_8b519_row6_col5 {
#   background-color: #69b369;
#   color: #f1f1f1;
# }
# #T_8b519_row7_col0 {
#   background-color: #078407;
#   color: #f1f1f1;
# }
# #T_8b519_row7_col1 {
#   background-color: #249224;
#   color: #f1f1f1;
# }
# #T_8b519_row7_col5 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_8b519_row8_col1 {
#   background-color: #1a8d1a;
#   color: #f1f1f1;
# }
# #T_8b519_row8_col4 {
#   background-color: #b1d7b1;
#   color: #000000;
# }
# #T_8b519_row8_col5 {
#   background-color: #63b163;
#   color: #f1f1f1;
# }
# #T_8b519_row9_col1 {
#   background-color: #2c962c;
#   color: #f1f1f1;
# }
# #T_8b519_row9_col2 {
#   background-color: #5dae5d;
#   color: #f1f1f1;
# }
# #T_8b519_row9_col3 {
#   background-color: #bddcbd;
#   color: #000000;
# }
# #T_8b519_row9_col5 {
#   background-color: #70b770;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8b519_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >all_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b519_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b519_row0_col0" class="data row0 col0" >0.3181</td>
#       <td id="T_8b519_row0_col1" class="data row0 col1" >0.6565</td>
#       <td id="T_8b519_row0_col2" class="data row0 col2" >0.4918</td>
#       <td id="T_8b519_row0_col3" class="data row0 col3" >0.4863</td>
#       <td id="T_8b519_row0_col4" class="data row0 col4" >0.6528</td>
#       <td id="T_8b519_row0_col5" class="data row0 col5" >0.5211</td>
#     </tr>
#     <tr>
#       <th id="T_8b519_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b519_row1_col0" class="data row1 col0" >0.7711</td>
#       <td id="T_8b519_row1_col1" class="data row1 col1" >0.8861</td>
#       <td id="T_8b519_row1_col2" class="data row1 col2" >0.8163</td>
#       <td id="T_8b519_row1_col3" class="data row1 col3" >0.5262</td>
#       <td id="T_8b519_row1_col4" class="data row1 col4" >0.8626</td>
#       <td id="T_8b519_row1_col5" class="data row1 col5" >0.7725</td>
#     </tr>
#     <tr>
#       <th id="T_8b519_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8b519_row2_col0" class="data row2 col0" >0.8514</td>
#       <td id="T_8b519_row2_col1" class="data row2 col1" >0.5950</td>
#       <td id="T_8b519_row2_col2" class="data row2 col2" >0.6534</td>
#       <td id="T_8b519_row2_col3" class="data row2 col3" >0.3326</td>
#       <td id="T_8b519_row2_col4" class="data row2 col4" >0.6136</td>
#       <td id="T_8b519_row2_col5" class="data row2 col5" >0.6092</td>
#     </tr>
#     <tr>
#       <th id="T_8b519_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8b519_row3_col0" class="data row3 col0" >0.6930</td>
#       <td id="T_8b519_row3_col1" class="data row3 col1" >0.5173</td>
#       <td id="T_8b519_row3_col2" class="data row3 col2" >0.5038</td>
#       <td id="T_8b519_row3_col3" class="data row3 col3" >0.2652</td>
#       <td id="T_8b519_row3_col4" class="data row3 col4" >0.7316</td>
#       <td id="T_8b519_row3_col5" class="data row3 col5" >0.5422</td>
#     </tr>
#     <tr>
#       <th id="T_8b519_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8b519_row4_col0" class="data row4 col0" >0.7414</td>
#       <td id="T_8b519_row4_col1" class="data row4 col1" >0.5963</td>
#       <td id="T_8b519_row4_col2" class="data row4 col2" >0.6665</td>
#       <td id="T_8b519_row4_col3" class="data row4 col3" >0.2330</td>
#       <td id="T_8b519_row4_col4" class="data row4 col4" >0.6127</td>
#       <td id="T_8b519_row4_col5" class="data row4 col5" >0.5700</td>
#     </tr>
#     <tr>
#       <th id="T_8b519_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8b519_row5_col0" class="data row5 col0" >0.3776</td>
#       <td id="T_8b519_row5_col1" class="data row5 col1" >0.4833</td>
#       <td id="T_8b519_row5_col2" class="data row5 col2" >0.3316</td>
#       <td id="T_8b519_row5_col3" class="data row5 col3" >0.1943</td>
#       <td id="T_8b519_row5_col4" class="data row5 col4" >0.4502</td>
#       <td id="T_8b519_row5_col5" class="data row5 col5" >0.3674</td>
#     </tr>
#     <tr>
#       <th id="T_8b519_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8b519_row6_col0" class="data row6 col0" >0.3994</td>
#       <td id="T_8b519_row6_col1" class="data row6 col1" >0.4984</td>
#       <td id="T_8b519_row6_col2" class="data row6 col2" >0.2886</td>
#       <td id="T_8b519_row6_col3" class="data row6 col3" >0.2227</td>
#       <td id="T_8b519_row6_col4" class="data row6 col4" >0.5180</td>
#       <td id="T_8b519_row6_col5" class="data row6 col5" >0.3854</td>
#     </tr>
#     <tr>
#       <th id="T_8b519_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8b519_row7_col0" class="data row7 col0" >0.5818</td>
#       <td id="T_8b519_row7_col1" class="data row7 col1" >0.5313</td>
#       <td id="T_8b519_row7_col2" class="data row7 col2" >0.3880</td>
#       <td id="T_8b519_row7_col3" class="data row7 col3" >0.1684</td>
#       <td id="T_8b519_row7_col4" class="data row7 col4" >0.5965</td>
#       <td id="T_8b519_row7_col5" class="data row7 col5" >0.4532</td>
#     </tr>
#     <tr>
#       <th id="T_8b519_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8b519_row8_col0" class="data row8 col0" >0.4484</td>
#       <td id="T_8b519_row8_col1" class="data row8 col1" >0.4189</td>
#       <td id="T_8b519_row8_col2" class="data row8 col2" >0.3826</td>
#       <td id="T_8b519_row8_col3" class="data row8 col3" >0.1857</td>
#       <td id="T_8b519_row8_col4" class="data row8 col4" >0.2508</td>
#       <td id="T_8b519_row8_col5" class="data row8 c

# %%
rob_effective = pd.DataFrame(rob_effective).T

show_gradient(
    rob_effective,
    N_ROW)
# Out:
# <style type="text/css">
# #T_6be86_row0_col0, #T_6be86_row1_col3, #T_6be86_row2_col3, #T_6be86_row3_col3, #T_6be86_row4_col3, #T_6be86_row5_col3, #T_6be86_row6_col3, #T_6be86_row7_col3, #T_6be86_row8_col3, #T_6be86_row9_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_6be86_row0_col1, #T_6be86_row1_col1 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_6be86_row0_col2, #T_6be86_row2_col1 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_6be86_row0_col3 {
#   background-color: #6eb66e;
#   color: #f1f1f1;
# }
# #T_6be86_row0_col4, #T_6be86_row1_col4, #T_6be86_row2_col0, #T_6be86_row3_col4, #T_6be86_row4_col0, #T_6be86_row5_col1, #T_6be86_row6_col4, #T_6be86_row7_col4, #T_6be86_row8_col0, #T_6be86_row9_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_6be86_row0_col5, #T_6be86_row3_col5 {
#   background-color: #8ac48a;
#   color: #000000;
# }
# #T_6be86_row1_col0 {
#   background-color: #99cb99;
#   color: #000000;
# }
# #T_6be86_row1_col2 {
#   background-color: #b3d8b3;
#   color: #000000;
# }
# #T_6be86_row1_col5 {
#   background-color: #9fce9f;
#   color: #000000;
# }
# #T_6be86_row2_col2 {
#   background-color: #91c791;
#   color: #000000;
# }
# #T_6be86_row2_col4 {
#   background-color: #80bf80;
#   color: #000000;
# }
# #T_6be86_row2_col5 {
#   background-color: #7cbd7c;
#   color: #000000;
# }
# #T_6be86_row3_col0 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_6be86_row3_col1 {
#   background-color: #7abc7a;
#   color: #000000;
# }
# #T_6be86_row3_col2 {
#   background-color: #78bb78;
#   color: #f1f1f1;
# }
# #T_6be86_row4_col1 {
#   background-color: #a6d1a6;
#   color: #000000;
# }
# #T_6be86_row4_col2 {
#   background-color: #cbe4cb;
#   color: #000000;
# }
# #T_6be86_row4_col4 {
#   background-color: #b2d7b1;
#   color: #000000;
# }
# #T_6be86_row4_col5 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_6be86_row5_col0 {
#   background-color: #96c996;
#   color: #000000;
# }
# #T_6be86_row5_col2, #T_6be86_row9_col5 {
#   background-color: #70b770;
#   color: #f1f1f1;
# }
# #T_6be86_row5_col4 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_6be86_row5_col5 {
#   background-color: #8fc68f;
#   color: #000000;
# }
# #T_6be86_row6_col0 {
#   background-color: #86c286;
#   color: #000000;
# }
# #T_6be86_row6_col1 {
#   background-color: #d0e6d0;
#   color: #000000;
# }
# #T_6be86_row6_col2 {
#   background-color: #339933;
#   color: #f1f1f1;
# }
# #T_6be86_row6_col5 {
#   background-color: #7ebe7e;
#   color: #000000;
# }
# #T_6be86_row7_col0 {
#   background-color: #dfeddf;
#   color: #000000;
# }
# #T_6be86_row7_col1 {
#   background-color: #c1dfc1;
#   color: #000000;
# }
# #T_6be86_row7_col2 {
#   background-color: #77ba77;
#   color: #f1f1f1;
# }
# #T_6be86_row7_col5 {
#   background-color: #9acb9a;
#   color: #000000;
# }
# #T_6be86_row8_col1 {
#   background-color: #cce4cc;
#   color: #000000;
# }
# #T_6be86_row8_col2 {
#   background-color: #b0d6b0;
#   color: #000000;
# }
# #T_6be86_row8_col4 {
#   background-color: #3e9e3e;
#   color: #f1f1f1;
# }
# #T_6be86_row8_col5 {
#   background-color: #87c287;
#   color: #000000;
# }
# #T_6be86_row9_col1 {
#   background-color: #afd6af;
#   color: #000000;
# }
# #T_6be86_row9_col2 {
#   background-color: #7dbd7d;
#   color: #000000;
# }
# #T_6be86_row9_col3 {
#   background-color: #198c19;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6be86_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >all_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6be86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6be86_row0_col0" class="data row0 col0" >0.6763</td>
#       <td id="T_6be86_row0_col1" class="data row0 col1" >0.3151</td>
#       <td id="T_6be86_row0_col2" class="data row0 col2" >0.4963</td>
#       <td id="T_6be86_row0_col3" class="data row0 col3" >0.5036</td>
#       <td id="T_6be86_row0_col4" class="data row0 col4" >0.3095</td>
#       <td id="T_6be86_row0_col5" class="data row0 col5" >0.4602</td>
#     </tr>
#     <tr>
#       <th id="T_6be86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6be86_row1_col0" class="data row1 col0" >0.2098</td>
#       <td id="T_6be86_row1_col1" class="data row1 col1" >0.0775</td>
#       <td id="T_6be86_row1_col2" class="data row1 col2" >0.1647</td>
#       <td id="T_6be86_row1_col3" class="data row1 col3" >0.4651</td>
#       <td id="T_6be86_row1_col4" class="data row1 col4" >0.0716</td>
#       <td id="T_6be86_row1_col5" class="data row1 col5" >0.1977</td>
#     </tr>
#     <tr>
#       <th id="T_6be86_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6be86_row2_col0" class="data row2 col0" >0.1218</td>
#       <td id="T_6be86_row2_col1" class="data row2 col1" >0.3984</td>
#       <td id="T_6be86_row2_col2" class="data row2 col2" >0.3280</td>
#       <td id="T_6be86_row2_col3" class="data row2 col3" >0.6630</td>
#       <td id="T_6be86_row2_col4" class="data row2 col4" >0.3686</td>
#       <td id="T_6be86_row2_col5" class="data row2 col5" >0.3759</td>
#     </tr>
#     <tr>
#       <th id="T_6be86_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6be86_row3_col0" class="data row3 col0" >0.2906</td>
#       <td id="T_6be86_row3_col1" class="data row3 col1" >0.4764</td>
#       <td id="T_6be86_row3_col2" class="data row3 col2" >0.4813</td>
#       <td id="T_6be86_row3_col3" class="data row3 col3" >0.7316</td>
#       <td id="T_6be86_row3_col4" class="data row3 col4" >0.2415</td>
#       <td id="T_6be86_row3_col5" class="data row3 col5" >0.4443</td>
#     </tr>
#     <tr>
#       <th id="T_6be86_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6be86_row4_col0" class="data row4 col0" >0.2377</td>
#       <td id="T_6be86_row4_col1" class="data row4 col1" >0.3935</td>
#       <td id="T_6be86_row4_col2" class="data row4 col2" >0.3081</td>
#       <td id="T_6be86_row4_col3" class="data row4 col3" >0.7647</td>
#       <td id="T_6be86_row4_col4" class="data row4 col4" >0.3664</td>
#       <td id="T_6be86_row4_col5" class="data row4 col5" >0.4141</td>
#     </tr>
#     <tr>
#       <th id="T_6be86_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6be86_row5_col0" class="data row5 col0" >0.6155</td>
#       <td id="T_6be86_row5_col1" class="data row5 col1" >0.5099</td>
#       <td id="T_6be86_row5_col2" class="data row5 col2" >0.6627</td>
#       <td id="T_6be86_row5_col3" class="data row5 col3" >0.8036</td>
#       <td id="T_6be86_row5_col4" class="data row5 col4" >0.5353</td>
#       <td id="T_6be86_row5_col5" class="data row5 col5" >0.6254</td>
#     </tr>
#     <tr>
#       <th id="T_6be86_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6be86_row6_col0" class="data row6 col0" >0.5916</td>
#       <td id="T_6be86_row6_col1" class="data row6 col1" >0.4909</td>
#       <td id="T_6be86_row6_col2" class="data row6 col2" >0.7046</td>
#       <td id="T_6be86_row6_col3" class="data row6 col3" >0.7744</td>
#       <td id="T_6be86_row6_col4" class="data row6 col4" >0.4546</td>
#       <td id="T_6be86_row6_col5" class="data row6 col5" >0.6032</td>
#     </tr>
#     <tr>
#       <th id="T_6be86_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6be86_row7_col0" class="data row7 col0" >0.4077</td>
#       <td id="T_6be86_row7_col1" class="data row7 col1" >0.4634</td>
#       <td id="T_6be86_row7_col2" class="data row7 col2" >0.6043</td>
#       <td id="T_6be86_row7_col3" class="data row7 col3" >0.8302</td>
#       <td id="T_6be86_row7_col4" class="data row7 col4" >0.3845</td>
#       <td id="T_6be86_row7_col5" class="data row7 col5" >0.5380</td>
#     </tr>
#     <tr>
#       <th id="T_6be86_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6be86_row8_col0" class="data row8 col0" >0.5397</td>
#       <td id="T_6be86_row8_col1" class="data row8 col1" >0.5754</td>
#       <td id="T_6be86_row8_col2" class="data row8 col2" >0.6081</td>
#       <td id="T_6be86_row8_col3" class="data row8 col3" >0.8121</td>
#       <td id="T_6be8

# %% [markdown]
# # LGBM

# %%
import os
import pandas as pd
import numpy as np

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.metrics import log_loss

import gensim
from scipy import sparse
import lightgbm as lgb

import warnings
warnings.filterwarnings('ignore')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
class CFG:
    seed = 42
    n_folds = 4
    
INPUT_DIR = "../input/feedback-prize-effectiveness/"

def get_train_essay(essay_id):
    essay_path = os.path.join(INPUT_DIR,f'train/{essay_id}.txt')
    essay_text = open(essay_path,'r').read()
    return essay_text

def get_test_essay(essay_id):
    essay_path = os.path.join(INPUT_DIR,f'test/{essay_id}.txt')
    essay_text = open(essay_path,'r').read()
    return essay_text

train = pd.read_csv(INPUT_DIR+'train.csv')
test = pd.read_csv(INPUT_DIR+'test.csv')
train['essay_text'] = train['essay_id'].apply(get_train_essay)
test['essay_text'] = test['essay_id'].apply(get_test_essay)

def set_seed(seed=42):
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(CFG.seed)

effectiveness_map = {'Ineffective':0, 'Adequate':1, 'Effective':2}
train['target'] = train['discourse_effectiveness'].map(effectiveness_map)

sgkf = StratifiedGroupKFold(n_splits=CFG.n_folds,shuffle=True,random_state=CFG.seed)

for fold, (_,val_idx) in enumerate(sgkf.split(X=train, y=train['target'], groups=train.essay_id)):
    train.loc[val_idx,'kfold'] = fold

word2vec_model = gensim.models.KeyedVectors.load_word2vec_format('../input/google-news/GoogleNews-vectors-negative300.bin', binary=True)
print(word2vec_model.vectors.shape)

def avg_feature_vector(sentence, model, num_features):
    words = sentence.replace('\n'," ").replace(',',' ').replace('.'," ").split()
    feature_vec = np.zeros((num_features,),dtype="float32")
    i=0
    for word in words:
        try:
            feature_vec = np.add(feature_vec, model[word])
        except KeyError as error:
            feature_vec 
            i = i + 1
    if len(words) > 0:
        feature_vec = np.divide(feature_vec, len(words)- i)
    return feature_vec

params = {}
params["objective"] = 'multiclass'
params['metric'] = 'multi_logloss'
params['boosting'] = 'gbdt'
params['num_class'] = 3
params['is_unbalance'] = True
params["learning_rate"] = 0.05
params["lambda_l2"] = 0.0256
params["num_leaves"] = 52
params["max_depth"] = 10
params["feature_fraction"] = 0.503
params["bagging_fraction"] = 0.741
params["bagging_freq"] = 8
params["bagging_seed"] = 10
params["min_data_in_leaf"] = 10
params["verbosity"] = -1
params["random_state"] = 42
num_rounds = 1000

oof_score = 0
y_test_pred = np.zeros((test.shape[0], 3))

for fold in range(CFG.n_folds):
    print(f'=============fold:{fold}==================')
    train_fold=train[train['kfold']!=fold].reset_index(drop=True)
    valid_fold=train[train['kfold']==fold].reset_index(drop=True)

    #word2vec

    #discourse_text
    word2vec_train_disc_text = np.zeros((len(train_fold.index),300),dtype="float32")
    word2vec_valid_disc_text = np.zeros((len(valid_fold.index),300),dtype="float32")
    word2vec_test_disc_text = np.zeros((len(test.index),300),dtype="float32")
    for i in range(len(train_fold.index)):
        word2vec_train_disc_text[i] = avg_feature_vector(train_fold["discourse_text"][i], word2vec_model, 300)
    for i in range(len(valid_fold.index)):
        word2vec_valid_disc_text[i] = avg_feature_vector(valid_fold["discourse_text"][i], word2vec_model, 300)
    for i in range(len(test.index)):
        word2vec_test_disc_text[i] = avg_feature_vector(test["discourse_text"][i], word2vec_model, 300)

    #essay_text
    word2vec_train_essay_text = np.zeros((len(train_fold.index),300),dtype="float32")
    word2vec_valid_essay_text = np.zeros((len(valid_fold.index),300),dtype="float32")
    word2vec_test_essay_text = np.zeros((len(test.index),300),dtype="float32")
    for i in range(len(train_fold.index)):
        word2vec_train_essay_text[i] = avg_feature_vector(train_fold["essay_text"][i], word2vec_model, 300)
    for i in range(len(valid_fold.index)):
        word2vec_valid_essay_text[i] = avg_feature_vector(valid_fold["essay_text"][i], word2vec_model, 300)
    for i in range(len(test.index)):
        word2vec_test_essay_text[i] = avg_feature_vector(test["essay_text"][i], word2vec_model, 300)

    #OneHot
    ohe = OneHotEncoder()
    train_type_ohe=sparse.csr_matrix(ohe.fit_transform(train_fold['discourse_type'].values.reshape(-1,1)))
    valid_type_ohe=sparse.csr_matrix(ohe.transform(valid_fold['discourse_type'].values.reshape(-1,1)))
    test_type_ohe=sparse.csr_matrix(ohe.transform(test['discourse_type'].values.reshape(-1,1)))


    #merge
    Xtrain_word2vec = sparse.hstack((train_type_ohe,word2vec_train_disc_text,word2vec_train_essay_text))
    Xvalid_word2vec = sparse.hstack((valid_type_ohe,word2vec_valid_disc_text,word2vec_valid_essay_text))
    test_word2vec = sparse.hstack((test_type_ohe,word2vec_test_disc_text,word2vec_test_essay_text))

    #lgbm
    lgtrain = lgb.Dataset(Xtrain_word2vec, label=train_fold['target'].ravel())
    lgvalidation = lgb.Dataset(Xvalid_word2vec, label=valid_fold['target'].ravel())

    model = lgb.train(params, lgtrain, num_rounds, 
                    valid_sets=[lgtrain, lgvalidation], 
                    early_stopping_rounds=100, verbose_eval=100)

    y_pred = model.predict(Xvalid_word2vec, num_iteration=model.best_iteration)
    y_test_pred += model.predict(test_word2vec, num_iteration=model.best_iteration)

    score = log_loss(valid_fold['target'], y_pred)
    oof_score += score

    print(f'Fold:{fold},valid score:{score}')
    
y_test_pred = y_test_pred / float(CFG.n_folds)
oof_score /= float(CFG.n_folds)
print("Aggregate OOF Score: {}".format(oof_score))
# Out:
# (3000000, 300)
# =============fold:0==================
# Training until validation scores don't improve for 100 rounds
# [100]	training's multi_logloss: 0.460002	valid_1's multi_logloss: 0.748048
# [200]	training's multi_logloss: 0.313471	valid_1's multi_logloss: 0.732728
# [300]	training's multi_logloss: 0.221816	valid_1's multi_logloss: 0.735344
# Early stopping, best iteration is:
# [236]	training's multi_logloss: 0.275861	valid_1's multi_logloss: 0.731422
# Fold:0,valid score:0.7314221251391888
# =============fold:1==================
# Training until validation scores don't improve for 100 rounds
# [100]	training's multi_logloss: 0.462338	valid_1's multi_logloss: 0.738764
# [200]	training's multi_logloss: 0.316004	valid_1's multi_logloss: 0.724543
# [300]	training's multi_logloss: 0.224546	valid_1's multi_logloss: 0.725092
# Early stopping, best iteration is:
# [255]	training's multi_logloss: 0.261299	valid_1's multi_logloss: 0.723197
# Fold:1,valid score:0.7231967256840189
# =============fold:2==================
# Training until validation scores don't improve for 100 rounds
# [100]	training's multi_logloss: 0.461596	valid_1's multi_logloss: 0.762237
# [200]	training's multi_logloss: 0.3159	valid_1's multi_logloss: 0.753211
# [300]	training's multi_logloss: 0.223354	valid_1's multi_logloss: 0.754198
# Early stopping, best iteration is:
# [222]	training's multi_logloss: 0.292309	valid_1's multi_logloss: 0.752066
# Fold:2,valid score:0.7520661041596963
# =============fold:3==================
# Training until validation scores don't improve for 100 rounds
# [100]	training's multi_logloss: 0.468285	valid_1's multi_logloss: 0.732232
# [200]	training's multi_logloss: 0.321179	valid_1's multi_logloss: 0.720807
# [300]	training's multi_logloss: 0.227368	valid_1's multi_logloss: 0.722765
# Early stopping, best iteration is:
# [206]	training's multi_logloss: 0.314419	valid_1's multi_logloss: 0.720495
# Fold:3,valid score:0.7204945877168054
# Aggregate OOF Score: 0.7317948856749275

# %%
lgbm_ineffective = y_test_pred[:,0]
lgbm_adequate = y_test_pred[:,1]
lgbm_effective = y_test_pred[:,2]

lgbm_ineffective = pd.DataFrame(lgbm_ineffective)
lgbm_adequate = pd.DataFrame(lgbm_adequate)
lgbm_effective = pd.DataFrame(lgbm_effective)

# %%
lgbm_ineffective
# Out:
#         0
# 0  0.0246
# 1  0.0208
# 2  0.0245
# 3  0.0790
# 4  0.0554
# 5  0.0275
# 6  0.0320
# 7  0.0287
# 8  0.0539
# 9  0.0208

# %% [markdown]
# # 4. Create submission

# %%
level_names = ['deberta', 'roberta', 'lgbm']

ineffective_ = pd.concat(
    [deb_ineffective, rob_ineffective, lgbm_ineffective],
    keys=level_names, axis=1
)

adequate_ = pd.concat(
    [deb_adequate, rob_adequate, lgbm_adequate],
    keys=level_names, axis=1
)

effective_ = pd.concat(
    [deb_effective, rob_effective, lgbm_effective],
    keys=level_names, axis=1
)

# %%
show_gradient(
    ineffective_,
    N_ROW
)
# Out:
# <style type="text/css">
# #T_f887b_row0_col0 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_f887b_row0_col1 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_f887b_row0_col2 {
#   background-color: #95c995;
#   color: #000000;
# }
# #T_f887b_row0_col3, #T_f887b_row1_col7, #T_f887b_row2_col7, #T_f887b_row3_col7, #T_f887b_row4_col7, #T_f887b_row5_col7, #T_f887b_row6_col7, #T_f887b_row7_col7, #T_f887b_row8_col7, #T_f887b_row9_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_f887b_row0_col4 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_f887b_row0_col5, #T_f887b_row4_col9 {
#   background-color: #3e9e3e;
#   color: #f1f1f1;
# }
# #T_f887b_row0_col6, #T_f887b_row6_col5 {
#   background-color: #acd4ac;
#   color: #000000;
# }
# #T_f887b_row0_col7, #T_f887b_row5_col0, #T_f887b_row6_col2 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_f887b_row0_col8, #T_f887b_row1_col8, #T_f887b_row2_col0, #T_f887b_row2_col1, #T_f887b_row3_col1, #T_f887b_row3_col9, #T_f887b_row4_col2, #T_f887b_row5_col9, #T_f887b_row6_col9, #T_f887b_row7_col2, #T_f887b_row8_col9, #T_f887b_row9_col8 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_f887b_row0_col9 {
#   background-color: #57ab57;
#   color: #f1f1f1;
# }
# #T_f887b_row0_col10, #T_f887b_row8_col1 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_f887b_row1_col0 {
#   background-color: #58ab58;
#   color: #f1f1f1;
# }
# #T_f887b_row1_col1 {
#   background-color: #b0d6b0;
#   color: #000000;
# }
# #T_f887b_row1_col2 {
#   background-color: #61b061;
#   color: #f1f1f1;
# }
# #T_f887b_row1_col3, #T_f887b_row3_col4 {
#   background-color: #c2dfc2;
#   color: #000000;
# }
# #T_f887b_row1_col4, #T_f887b_row1_col6, #T_f887b_row9_col7 {
#   background-color: #c0dec0;
#   color: #000000;
# }
# #T_f887b_row1_col5, #T_f887b_row5_col8 {
#   background-color: #78bb78;
#   color: #000000;
# }
# #T_f887b_row1_col9 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_f887b_row1_col10 {
#   background-color: #94c994;
#   color: #000000;
# }
# #T_f887b_row2_col2 {
#   background-color: #098509;
#   color: #f1f1f1;
# }
# #T_f887b_row2_col3, #T_f887b_row9_col4 {
#   background-color: #59ac59;
#   color: #f1f1f1;
# }
# #T_f887b_row2_col4 {
#   background-color: #0b850b;
#   color: #f1f1f1;
# }
# #T_f887b_row2_col5 {
#   background-color: #d5e9d5;
#   color: #000000;
# }
# #T_f887b_row2_col6 {
#   background-color: #5dae5d;
#   color: #f1f1f1;
# }
# #T_f887b_row2_col8 {
#   background-color: #65b265;
#   color: #f1f1f1;
# }
# #T_f887b_row2_col9 {
#   background-color: #229122;
#   color: #f1f1f1;
# }
# #T_f887b_row2_col10 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_f887b_row3_col0 {
#   background-color: #52a852;
#   color: #f1f1f1;
# }
# #T_f887b_row3_col2 {
#   background-color: #0f870f;
#   color: #f1f1f1;
# }
# #T_f887b_row3_col3 {
#   background-color: #058205;
#   color: #f1f1f1;
# }
# #T_f887b_row3_col5, #T_f887b_row9_col3 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_f887b_row3_col6 {
#   background-color: #c7e1c7;
#   color: #000000;
# }
# #T_f887b_row3_col8, #T_f887b_row8_col10 {
#   background-color: #a1cfa1;
#   color: #000000;
# }
# #T_f887b_row3_col10 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_f887b_row4_col0 {
#   background-color: #8bc48b;
#   color: #000000;
# }
# #T_f887b_row4_col1 {
#   background-color: #40a040;
#   color: #f1f1f1;
# }
# #T_f887b_row4_col3 {
#   background-color: #53a953;
#   color: #f1f1f1;
# }
# #T_f887b_row4_col4 {
#   background-color: #afd6af;
#   color: #000000;
# }
# #T_f887b_row4_col5, #T_f887b_row7_col5 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_f887b_row4_col6 {
#   background-color: #9fce9f;
#   color: #000000;
# }
# #T_f887b_row4_col8 {
#   background-color: #aed5ae;
#   color: #000000;
# }
# #T_f887b_row4_col10 {
#   background-color: #82c082;
#   color: #000000;
# }
# #T_f887b_row5_col1, #T_f887b_row7_col4 {
#   background-color: #b1d7b1;
#   color: #000000;
# }
# #T_f887b_row5_col2 {
#   background-color: #359a35;
#   color: #f1f1f1;
# }
# #T_f887b_row5_col3 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_f887b_row5_col4 {
#   background-color: #bdddbd;
#   color: #000000;
# }
# #T_f887b_row5_col5, #T_f887b_row8_col4 {
#   background-color: #bfdebf;
#   color: #000000;
# }
# #T_f887b_row5_col6, #T_f887b_row9_col5 {
#   background-color: #c9e3c9;
#   color: #000000;
# }
# #T_f887b_row5_col10 {
#   background-color: #9acb9a;
#   color: #000000;
# }
# #T_f887b_row6_col0 {
#   background-color: #d9ead9;
#   color: #000000;
# }
# #T_f887b_row6_col1 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_f887b_row6_col3 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_f887b_row6_col4 {
#   background-color: #badbba;
#   color: #000000;
# }
# #T_f887b_row6_col6 {
#   background-color: #cbe4cb;
#   color: #000000;
# }
# #T_f887b_row6_col8 {
#   background-color: #259225;
#   color: #f1f1f1;
# }
# #T_f887b_row6_col10 {
#   background-color: #a4d0a4;
#   color: #000000;
# }
# #T_f887b_row7_col0 {
#   background-color: #99cb99;
#   color: #000000;
# }
# #T_f887b_row7_col1 {
#   background-color: #a0cea0;
#   color: #000000;
# }
# #T_f887b_row7_col3 {
#   background-color: #6db66d;
#   color: #f1f1f1;
# }
# #T_f887b_row7_col6, #T_f887b_row8_col0 {
#   background-color: #c3e0c3;
#   color: #000000;
# }
# #T_f887b_row7_col8 {
#   background-color: #7abc7a;
#   color: #000000;
# }
# #T_f887b_row7_col9 {
#   background-color: #3c9d3c;
#   color: #f1f1f1;
# }
# #T_f887b_row7_col10 {
#   background-color: #8ec58e;
#   color: #000000;
# }
# #T_f887b_row8_col2 {
#   background-color: #1d8e1d;
#   color: #f1f1f1;
# }
# #T_f887b_row8_col3 {
#   background-color: #b2d7b1;
#   color: #000000;
# }
# #T_f887b_row8_col5 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_f887b_row8_col6 {
#   background-color: #cae3ca;
#   color: #000000;
# }
# #T_f887b_row8_col8 {
#   background-color: #cde5cd;
#   color: #000000;
# }
# #T_f887b_row9_col1 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_f887b_row9_col2 {
#   background-color: #e0eedf;
#   color: #000000;
# }
# #T_f887b_row9_col6 {
#   background-color: #bddcbd;
#   color: #000000;
# }
# #T_f887b_row9_col9 {
#   background-color: #80bf80;
#   color: #000000;
# }
# #T_f887b_row9_col10 {
#   background-color: #aad3aa;
#   color: #000000;
# }
# </style>
# <table id="T_f887b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="4">deberta</th>
#       <th class="col_heading level0 col4" colspan="5">roberta</th>
#       <th class="col_heading level0 col9" >lgbm</th>
#       <th class="col_heading level0 col10" >all_mean</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >0</th>
#       <th class="col_heading level1 col1" >1</th>
#       <th class="col_heading level1 col2" >2</th>
#       <th class="col_heading level1 col3" >3</th>
#       <th class="col_heading level1 col4" >0</th>
#       <th class="col_heading level1 col5" >1</th>
#       <th class="col_heading level1 col6" >2</th>
#       <th class="col_heading level1 col7" >3</th>
#       <th class="col_heading level1 col8" >4</th>
#       <th class="col_heading level1 col9" >0</th>
#       <th class="col_heading level1 col10" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f887b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f887b_row0_col0" class="data row0 col0" >0.0026</td>
#       <td id="T_f887b_row0_col1" class="data row0 col1" >0.0037</td>
#       <td id="T_f887b_row0_col2" class="data row0 col2" >0.0154</td>
#       <td id="T_f887b_row0_col3" class="data row0 col3" >0.0025</td>
#       <td id="T_f887b_row0_col4" class="data row0 col4" >0.0055</td>
#       <td id="T_f887b_row0_col5" class="data row0 col5" >0.0284</td>
#       <td id="T_f887b_row0_col6" class="data row0 col6" >0.0119</td>
#       <td id="T_f887b_row0_col7" class="data row0 col7" >0.0101</td>
#       <td id="T_f887b_row0_col8" class="data row0 col8" >0.0377</td>
#       <td id="T_f887b_row0_col9" class="data row0 col9" >0.0246</td>
#       <td id="T_f887b_row0_col10" class="data row0 col10" >0.0142</td>
#     </tr>
#     <tr>
#       <th id="T_f887b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f887b_row1_col0" class="data row1 col0" >0.0443</td>
#       <td id="T_f887b_row1_col1" class="data row1 col1" >0.0230</td>
#       <td id="T_f887b_row1_col2" class="data row1 col2"

# %%
show_gradient(
    adequate_,
    N_ROW
)
# Out:
# <style type="text/css">
# #T_115ba_row0_col0, #T_115ba_row1_col7, #T_115ba_row2_col7, #T_115ba_row3_col7, #T_115ba_row4_col7, #T_115ba_row5_col7, #T_115ba_row6_col3, #T_115ba_row7_col7, #T_115ba_row8_col7, #T_115ba_row9_col9 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_115ba_row0_col1 {
#   background-color: #bbdcbb;
#   color: #000000;
# }
# #T_115ba_row0_col2 {
#   background-color: #80bf80;
#   color: #000000;
# }
# #T_115ba_row0_col3 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_115ba_row0_col4 {
#   background-color: #c9e3c9;
#   color: #000000;
# }
# #T_115ba_row0_col5, #T_115ba_row1_col3, #T_115ba_row2_col4, #T_115ba_row3_col1, #T_115ba_row4_col4, #T_115ba_row5_col5, #T_115ba_row6_col8, #T_115ba_row7_col3, #T_115ba_row8_col2, #T_115ba_row9_col4 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_115ba_row0_col6 {
#   background-color: #61b061;
#   color: #f1f1f1;
# }
# #T_115ba_row0_col7 {
#   background-color: #65b265;
#   color: #f1f1f1;
# }
# #T_115ba_row0_col8, #T_115ba_row4_col1 {
#   background-color: #028102;
#   color: #f1f1f1;
# }
# #T_115ba_row0_col9 {
#   background-color: #99cb99;
#   color: #000000;
# }
# #T_115ba_row0_col10 {
#   background-color: #85c185;
#   color: #000000;
# }
# #T_115ba_row1_col0 {
#   background-color: #178b17;
#   color: #f1f1f1;
# }
# #T_115ba_row1_col1, #T_115ba_row2_col3, #T_115ba_row3_col8 {
#   background-color: #068306;
#   color: #f1f1f1;
# }
# #T_115ba_row1_col2 {
#   background-color: #309730;
#   color: #f1f1f1;
# }
# #T_115ba_row1_col4 {
#   background-color: #58ab58;
#   color: #f1f1f1;
# }
# #T_115ba_row1_col5, #T_115ba_row3_col0 {
#   background-color: #148a14;
#   color: #f1f1f1;
# }
# #T_115ba_row1_col6, #T_115ba_row2_col0 {
#   background-color: #3e9e3e;
#   color: #f1f1f1;
# }
# #T_115ba_row1_col8, #T_115ba_row4_col6 {
#   background-color: #229122;
#   color: #f1f1f1;
# }
# #T_115ba_row1_col9 {
#   background-color: #3f9f3f;
#   color: #f1f1f1;
# }
# #T_115ba_row1_col10 {
#   background-color: #3a9c3a;
#   color: #f1f1f1;
# }
# #T_115ba_row2_col1 {
#   background-color: #058205;
#   color: #f1f1f1;
# }
# #T_115ba_row2_col2 {
#   background-color: #63b163;
#   color: #f1f1f1;
# }
# #T_115ba_row2_col5 {
#   background-color: #74b974;
#   color: #f1f1f1;
# }
# #T_115ba_row2_col6 {
#   background-color: #59ac59;
#   color: #f1f1f1;
# }
# #T_115ba_row2_col8, #T_115ba_row9_col1 {
#   background-color: #6cb56c;
#   color: #f1f1f1;
# }
# #T_115ba_row2_col9 {
#   background-color: #97ca97;
#   color: #000000;
# }
# #T_115ba_row2_col10 {
#   background-color: #57ab57;
#   color: #f1f1f1;
# }
# #T_115ba_row3_col2, #T_115ba_row4_col10 {
#   background-color: #46a246;
#   color: #f1f1f1;
# }
# #T_115ba_row3_col3 {
#   background-color: #0c860c;
#   color: #f1f1f1;
# }
# #T_115ba_row3_col4 {
#   background-color: #1a8d1a;
#   color: #f1f1f1;
# }
# #T_115ba_row3_col5 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_115ba_row3_col6, #T_115ba_row7_col9, #T_115ba_row9_col8 {
#   background-color: #76ba76;
#   color: #f1f1f1;
# }
# #T_115ba_row3_col9 {
#   background-color: #aed5ae;
#   color: #000000;
# }
# #T_115ba_row3_col10 {
#   background-color: #4da64d;
#   color: #f1f1f1;
# }
# #T_115ba_row4_col0, #T_115ba_row4_col5 {
#   background-color: #43a143;
#   color: #f1f1f1;
# }
# #T_115ba_row4_col2, #T_115ba_row9_col6 {
#   background-color: #2e972e;
#   color: #f1f1f1;
# }
# #T_115ba_row4_col3, #T_115ba_row5_col4 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_115ba_row4_col8, #T_115ba_row7_col2 {
#   background-color: #3b9d3b;
#   color: #f1f1f1;
# }
# #T_115ba_row4_col9, #T_115ba_row5_col10, #T_115ba_row7_col0 {
#   background-color: #64b164;
#   color: #f1f1f1;
# }
# #T_115ba_row5_col0, #T_115ba_row8_col9 {
#   background-color: #8fc68f;
#   color: #000000;
# }
# #T_115ba_row5_col1 {
#   background-color: #359a35;
#   color: #f1f1f1;
# }
# #T_115ba_row5_col2 {
#   background-color: #289328;
#   color: #f1f1f1;
# }
# #T_115ba_row5_col3, #T_115ba_row8_col5 {
#   background-color: #62b062;
#   color: #f1f1f1;
# }
# #T_115ba_row5_col6 {
#   background-color: #7bbc7b;
#   color: #000000;
# }
# #T_115ba_row5_col8 {
#   background-color: #1b8d1b;
#   color: #f1f1f1;
# }
# #T_115ba_row5_col9 {
#   background-color: #c9e2c8;
#   color: #000000;
# }
# #T_115ba_row6_col0 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_115ba_row6_col1 {
#   background-color: #9acb9a;
#   color: #000000;
# }
# #T_115ba_row6_col2 {
#   background-color: #cce4cc;
#   color: #000000;
# }
# #T_115ba_row6_col4 {
#   background-color: #54a954;
#   color: #f1f1f1;
# }
# #T_115ba_row6_col5 {
#   background-color: #0e870e;
#   color: #f1f1f1;
# }
# #T_115ba_row6_col6 {
#   background-color: #a2cfa2;
#   color: #000000;
# }
# #T_115ba_row6_col7 {
#   background-color: #d1e6d1;
#   color: #000000;
# }
# #T_115ba_row6_col9 {
#   background-color: #8bc48b;
#   color: #000000;
# }
# #T_115ba_row6_col10 {
#   background-color: #8ec58e;
#   color: #000000;
# }
# #T_115ba_row7_col1 {
#   background-color: #0a850a;
#   color: #f1f1f1;
# }
# #T_115ba_row7_col4 {
#   background-color: #4ba54a;
#   color: #f1f1f1;
# }
# #T_115ba_row7_col5 {
#   background-color: #5eae5e;
#   color: #f1f1f1;
# }
# #T_115ba_row7_col6 {
#   background-color: #96c996;
#   color: #000000;
# }
# #T_115ba_row7_col8 {
#   background-color: #45a245;
#   color: #f1f1f1;
# }
# #T_115ba_row7_col10 {
#   background-color: #5bad5b;
#   color: #f1f1f1;
# }
# #T_115ba_row8_col0 {
#   background-color: #add5ad;
#   color: #000000;
# }
# #T_115ba_row8_col1 {
#   background-color: #389b38;
#   color: #f1f1f1;
# }
# #T_115ba_row8_col3 {
#   background-color: #71b771;
#   color: #f1f1f1;
# }
# #T_115ba_row8_col4 {
#   background-color: #52a852;
#   color: #f1f1f1;
# }
# #T_115ba_row8_col6 {
#   background-color: #78bb78;
#   color: #000000;
# }
# #T_115ba_row8_col8 {
#   background-color: #c5e0c5;
#   color: #000000;
# }
# #T_115ba_row8_col10 {
#   background-color: #79bc79;
#   color: #000000;
# }
# #T_115ba_row9_col0 {
#   background-color: #ddecdd;
#   color: #000000;
# }
# #T_115ba_row9_col2 {
#   background-color: #b6d9b6;
#   color: #000000;
# }
# #T_115ba_row9_col3 {
#   background-color: #7abc7a;
#   color: #000000;
# }
# #T_115ba_row9_col5 {
#   background-color: #168b16;
#   color: #f1f1f1;
# }
# #T_115ba_row9_col7 {
#   background-color: #5fae5f;
#   color: #f1f1f1;
# }
# #T_115ba_row9_col10 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_115ba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="4">deberta</th>
#       <th class="col_heading level0 col4" colspan="5">roberta</th>
#       <th class="col_heading level0 col9" >lgbm</th>
#       <th class="col_heading level0 col10" >all_mean</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >0</th>
#       <th class="col_heading level1 col1" >1</th>
#       <th class="col_heading level1 col2" >2</th>
#       <th class="col_heading level1 col3" >3</th>
#       <th class="col_heading level1 col4" >0</th>
#       <th class="col_heading level1 col5" >1</th>
#       <th class="col_heading level1 col6" >2</th>
#       <th class="col_heading level1 col7" >3</th>
#       <th class="col_heading level1 col8" >4</th>
#       <th class="col_heading level1 col9" >0</th>
#       <th class="col_heading level1 col10" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_115ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_115ba_row0_col0" class="data row0 col0" >0.2618</td>
#       <td id="T_115ba_row0_col1" class="data row0 col1" >0.3429</td>
#       <td id="T_115ba_row0_col2" class="data row0 col2" >0.4421</td>
#       <td id="T_115ba_row0_col3" class="data row0 col3" >0.2671</td>
#       <td id="T_115ba_row0_col4" class="data row0 col4" >0.3181</td>
#       <td id="T_115ba_row0_col5" class="data row0 col5" >0.6565</td>
#       <td id="T_115ba_row0_col6" class="data row0 col6" >0.4918</td>
#       <td id="T_115ba_row0_col7" class="data row0 col7" >0.4863</td>
#       <td id="T_115ba_row0_col8" class="data row0 col8" >0.6528</td>
#       <td id="T_115ba_row0_col9" class="data row0 col9" >0.4002</td>
#       <td id="T_115ba_row0_col10" class="data row0 col10" >0.4319</td>
#     </tr>
#     <tr>
#       <th id="T_115ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_115ba_row1_col0" class="data row1 col0" >0.8806</td>
#       <td id="T_115ba_row1_col1" class="data row1 col1" >0.9091</td>

# %%
show_gradient(
    effective_,
    N_ROW
)
# Out:
# <style type="text/css">
# #T_0ad10_row0_col0, #T_0ad10_row1_col7, #T_0ad10_row2_col7, #T_0ad10_row3_col7, #T_0ad10_row4_col7, #T_0ad10_row5_col7, #T_0ad10_row6_col3, #T_0ad10_row7_col7, #T_0ad10_row8_col7, #T_0ad10_row9_col9 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_0ad10_row0_col1 {
#   background-color: #2d962d;
#   color: #f1f1f1;
# }
# #T_0ad10_row0_col2, #T_0ad10_row3_col6, #T_0ad10_row9_col3 {
#   background-color: #6ab46a;
#   color: #f1f1f1;
# }
# #T_0ad10_row0_col3 {
#   background-color: #038103;
#   color: #f1f1f1;
# }
# #T_0ad10_row0_col4 {
#   background-color: #209020;
#   color: #f1f1f1;
# }
# #T_0ad10_row0_col5 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_0ad10_row0_col6 {
#   background-color: #84c084;
#   color: #000000;
# }
# #T_0ad10_row0_col7, #T_0ad10_row2_col8 {
#   background-color: #80bf80;
#   color: #000000;
# }
# #T_0ad10_row0_col8, #T_0ad10_row1_col3, #T_0ad10_row2_col4, #T_0ad10_row3_col1, #T_0ad10_row4_col1, #T_0ad10_row5_col5, #T_0ad10_row6_col8, #T_0ad10_row7_col3, #T_0ad10_row8_col2, #T_0ad10_row9_col4 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_0ad10_row0_col9 {
#   background-color: #58ab58;
#   color: #f1f1f1;
# }
# #T_0ad10_row0_col10 {
#   background-color: #64b164;
#   color: #f1f1f1;
# }
# #T_0ad10_row1_col0 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_0ad10_row1_col1 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# #T_0ad10_row1_col2 {
#   background-color: #c9e3c9;
#   color: #000000;
# }
# #T_0ad10_row1_col4, #T_0ad10_row2_col10 {
#   background-color: #94c994;
#   color: #000000;
# }
# #T_0ad10_row1_col5, #T_0ad10_row2_col3 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_0ad10_row1_col6 {
#   background-color: #afd6af;
#   color: #000000;
# }
# #T_0ad10_row1_col8 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_0ad10_row1_col9 {
#   background-color: #aed5ae;
#   color: #000000;
# }
# #T_0ad10_row1_col10 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_0ad10_row2_col0 {
#   background-color: #b0d6b0;
#   color: #000000;
# }
# #T_0ad10_row2_col1 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_0ad10_row2_col2, #T_0ad10_row5_col3, #T_0ad10_row5_col10 {
#   background-color: #8bc48b;
#   color: #000000;
# }
# #T_0ad10_row2_col5 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_0ad10_row2_col6, #T_0ad10_row4_col9 {
#   background-color: #91c791;
#   color: #000000;
# }
# #T_0ad10_row2_col9 {
#   background-color: #59ac59;
#   color: #f1f1f1;
# }
# #T_0ad10_row3_col0, #T_0ad10_row9_col5 {
#   background-color: #cee5ce;
#   color: #000000;
# }
# #T_0ad10_row3_col2 {
#   background-color: #add5ad;
#   color: #000000;
# }
# #T_0ad10_row3_col3 {
#   background-color: #e0eedf;
#   color: #000000;
# }
# #T_0ad10_row3_col4 {
#   background-color: #badbba;
#   color: #000000;
# }
# #T_0ad10_row3_col5, #T_0ad10_row6_col9 {
#   background-color: #6cb56c;
#   color: #f1f1f1;
# }
# #T_0ad10_row3_col8, #T_0ad10_row5_col2 {
#   background-color: #cfe5cf;
#   color: #000000;
# }
# #T_0ad10_row3_col9, #T_0ad10_row7_col6 {
#   background-color: #55a955;
#   color: #f1f1f1;
# }
# #T_0ad10_row3_col10 {
#   background-color: #99cb99;
#   color: #000000;
# }
# #T_0ad10_row4_col0 {
#   background-color: #a6d1a6;
#   color: #000000;
# }
# #T_0ad10_row4_col2 {
#   background-color: #cbe4cb;
#   color: #000000;
# }
# #T_0ad10_row4_col3 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_0ad10_row4_col4 {
#   background-color: #dfeddf;
#   color: #000000;
# }
# #T_0ad10_row4_col5 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_0ad10_row4_col6 {
#   background-color: #c1dfc1;
#   color: #000000;
# }
# #T_0ad10_row4_col8 {
#   background-color: #a8d2a8;
#   color: #000000;
# }
# #T_0ad10_row4_col10 {
#   background-color: #a5d1a5;
#   color: #000000;
# }
# #T_0ad10_row5_col0 {
#   background-color: #5eae5e;
#   color: #f1f1f1;
# }
# #T_0ad10_row5_col1, #T_0ad10_row9_col6 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_0ad10_row5_col4 {
#   background-color: #96c996;
#   color: #000000;
# }
# #T_0ad10_row5_col6 {
#   background-color: #70b770;
#   color: #f1f1f1;
# }
# #T_0ad10_row5_col8 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_0ad10_row5_col9 {
#   background-color: #369b36;
#   color: #f1f1f1;
# }
# #T_0ad10_row6_col0 {
#   background-color: #0f870f;
#   color: #f1f1f1;
# }
# #T_0ad10_row6_col1 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_0ad10_row6_col2 {
#   background-color: #1f8f1f;
#   color: #f1f1f1;
# }
# #T_0ad10_row6_col4, #T_0ad10_row7_col10 {
#   background-color: #90c790;
#   color: #000000;
# }
# #T_0ad10_row6_col5 {
#   background-color: #d3e7d3;
#   color: #000000;
# }
# #T_0ad10_row6_col6 {
#   background-color: #45a245;
#   color: #f1f1f1;
# }
# #T_0ad10_row6_col7 {
#   background-color: #178b17;
#   color: #f1f1f1;
# }
# #T_0ad10_row6_col10 {
#   background-color: #5bad5b;
#   color: #f1f1f1;
# }
# #T_0ad10_row7_col0, #T_0ad10_row9_col7 {
#   background-color: #87c287;
#   color: #000000;
# }
# #T_0ad10_row7_col1 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_0ad10_row7_col2 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_0ad10_row7_col4 {
#   background-color: #9ece9e;
#   color: #000000;
# }
# #T_0ad10_row7_col5 {
#   background-color: #8ac48a;
#   color: #000000;
# }
# #T_0ad10_row7_col8 {
#   background-color: #a7d2a7;
#   color: #000000;
# }
# #T_0ad10_row7_col9, #T_0ad10_row9_col8 {
#   background-color: #7bbc7b;
#   color: #000000;
# }
# #T_0ad10_row8_col0 {
#   background-color: #3c9d3c;
#   color: #f1f1f1;
# }
# #T_0ad10_row8_col1 {
#   background-color: #a9d3a9;
#   color: #000000;
# }
# #T_0ad10_row8_col3, #T_0ad10_row9_col10 {
#   background-color: #74b974;
#   color: #f1f1f1;
# }
# #T_0ad10_row8_col4 {
#   background-color: #8fc68f;
#   color: #000000;
# }
# #T_0ad10_row8_col5 {
#   background-color: #7cbd7c;
#   color: #000000;
# }
# #T_0ad10_row8_col6 {
#   background-color: #6bb46b;
#   color: #f1f1f1;
# }
# #T_0ad10_row8_col8 {
#   background-color: #259225;
#   color: #f1f1f1;
# }
# #T_0ad10_row8_col9 {
#   background-color: #6db66d;
#   color: #f1f1f1;
# }
# #T_0ad10_row8_col10 {
#   background-color: #6eb66e;
#   color: #f1f1f1;
# }
# #T_0ad10_row9_col0 {
#   background-color: #078407;
#   color: #f1f1f1;
# }
# #T_0ad10_row9_col1 {
#   background-color: #78bb78;
#   color: #000000;
# }
# #T_0ad10_row9_col2 {
#   background-color: #2e972e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0ad10_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="4">deberta</th>
#       <th class="col_heading level0 col4" colspan="5">roberta</th>
#       <th class="col_heading level0 col9" >lgbm</th>
#       <th class="col_heading level0 col10" >all_mean</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >0</th>
#       <th class="col_heading level1 col1" >1</th>
#       <th class="col_heading level1 col2" >2</th>
#       <th class="col_heading level1 col3" >3</th>
#       <th class="col_heading level1 col4" >0</th>
#       <th class="col_heading level1 col5" >1</th>
#       <th class="col_heading level1 col6" >2</th>
#       <th class="col_heading level1 col7" >3</th>
#       <th class="col_heading level1 col8" >4</th>
#       <th class="col_heading level1 col9" >0</th>
#       <th class="col_heading level1 col10" ></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ad10_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ad10_row0_col0" class="data row0 col0" >0.7356</td>
#       <td id="T_0ad10_row0_col1" class="data row0 col1" >0.6535</td>
#       <td id="T_0ad10_row0_col2" class="data row0 col2" >0.5426</td>
#       <td id="T_0ad10_row0_col3" class="data row0 col3" >0.7304</td>
#       <td id="T_0ad10_row0_col4" class="data row0 col4" >0.6763</td>
#       <td id="T_0ad10_row0_col5" class="data row0 col5" >0.3151</td>
#       <td id="T_0ad10_row0_col6" class="data row0 col6" >0.4963</td>
#       <td id="T_0ad10_row0_col7" class="data row0 col7" >0.5036</td>
#       <td id="T_0ad10_row0_col8" class="data row0 col8" >0.3095</td>
#       <td id="T_0ad10_row0_col9" class="data row0 col9" >0.5752</td>
#       <td id="T_0ad10_row0_col10" class="data row0 col10" >0.5538</td>
#     </tr>
#     <tr>
#       <th id="T_0ad10_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0ad10_row1_col0" class="data row1 col0" >0.0751</td>
#       <td id="T_0ad10_row

# %%
submission = submission_origin.copy()

w_ = [.65, .25, .10]  # ['deberta', 'roberta', 'gbm']
d_ = [('Ineffective', ineffective_),
      ('Adequate', adequate_),
      ('Effective', effective_)]

for x in d_:
    col_name, df = x
    submission[col_name] = pd.DataFrame(
        {col: df[col].mean(axis=1) for col in level_names}
    ).mul(w_).sum(axis=1)    

submission.head(N_ROW)
# Out:
#    discourse_id  Ineffective  Adequate  Effective
# 0  a261b6e14276       0.0111    0.3838     0.6052
# 1  5a88900e7dc1       0.0303    0.8512     0.1185
# 2  9790d835736b       0.0227    0.6952     0.2821
# 3  75ce6d68b67b       0.0573    0.6251     0.3176
# 4  93578d946723       0.0436    0.6058     0.3506
# 5  2e214524dbe3       0.0119    0.3626     0.6255
# 6  84812fc2ab9f       0.0106    0.2786     0.7108
# 7  c668ff840720       0.0191    0.5929     0.3880
# 8  739a6d00f44a       0.0224    0.4059     0.5717
# 9  bcfae2c9a244       0.0135    0.6128     0.3736

# %%
# 0	a261b6e14276	0.0102	0.3887	0.5911
# 1	5a88900e7dc1	0.0309	0.8405	0.1185
# 2	9790d835736b	0.0217	0.6997	0.2686
# 3	75ce6d68b67b	0.0512	0.6365	0.3023
# 4	93578d946723	0.0399	0.6053	0.3448
# 5	2e214524dbe3	0.0099	0.3721	0.6080
# 6	84812fc2ab9f	0.0084	0.2796	0.7020
# 7	c668ff840720	0.0171	0.5888	0.3841
# 8	739a6d00f44a	0.0178	0.4030	0.5692
# 9	bcfae2c9a244	0.0132	0.6373	0.3395

# %%
submission.to_csv('submission.csv',index=False)
